# %% [markdown]
# #**Imports**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline

pd.set_option('display.max_columns',200)
pd.set_option("display.max_info_rows", 800)
pd.set_option('display.max_info_columns',800)

from sklearn import set_config
set_config(transform_output='pandas')

# %% [markdown]
# #**Define Custom Functions**

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def classification_metrics(y_true, y_pred, label='',
                           output_dict=False, figsize=(8,4),
                           normalize='true', cmap='Blues',
                           colorbar=False):
    # Get the classification report
    report = classification_report(y_true, y_pred)
    ## Print header and report
    header = "-"*70
    print(header, f" Classification Metrics: {label}", header, sep='\n')
    print(report)
    ## CONFUSION MATRICES SUBPLOTS
    fig, axes = plt.subplots(ncols=2, figsize=figsize)
    # create a confusion matrix  of raw counts
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred,
                normalize=None, cmap='gist_gray', colorbar=colorbar,
                ax = axes[0],);
    axes[0].set_title("Raw Counts")
    # create a confusion matrix with the test data
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred,
                normalize=normalize, cmap=cmap, colorbar=colorbar,
                ax = axes[1]);
    axes[1].set_title("Normalized Confusion Matrix")
    # Adjust layout and show figure
    fig.tight_layout()
    plt.show()
    # Return dictionary of classification_report
    if output_dict==True:
        report_dict = classification_report(y_true, y_pred, output_dict=True)
        return report_dict


def evaluate_classification(model, X_train, y_train, X_test, y_test,
                         figsize=(6,4), normalize='true', output_dict = False,
                            cmap_train='Blues', cmap_test="Reds",colorbar=False):
    # Get predictions for training data
    y_train_pred = model.predict(X_train)
    # Call the helper function to obtain regression metrics for training data
    results_train = classification_metrics(y_train, y_train_pred, #verbose = verbose,
                                     output_dict=True, figsize=figsize,
                                         colorbar=colorbar, cmap=cmap_train,
                                     label='Training Data')
    print()
    # Get predictions for test data
    y_test_pred = model.predict(X_test)
    # Call the helper function to obtain regression metrics for test data
    results_test = classification_metrics(y_test, y_test_pred, #verbose = verbose,
                                  output_dict=True,figsize=figsize,
                                         colorbar=colorbar, cmap=cmap_test,
                                    label='Test Data' )
    if output_dict == True:
        # Store results in a dataframe if ouput_frame is True
        results_dict = {'train':results_train,
                    'test': results_test}
        return results_dict

# %% [markdown]
# #**Load the Dataset**

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Data
df = pd.read_csv('/content/drive/MyDrive/AXSOSACADEMY/02-IntroML/pd_speech_features.csv')
df.head()
# Out:
#    id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0   0       1  0.85247  0.71826  0.57227        240               239
# 1   0       1  0.76686  0.69481  0.53966        234               233
# 2   0       1  0.85083  0.67604  0.58982        232               231
# 3   1       0  0.41121  0.79672  0.59257        178               177
# 4   1       0  0.32790  0.79782  0.53028        236               235
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  \
# 0          0.008064            0.000087       0.00218      0.000018
# 1          0.008258            0.000073       0.00195      0.000016
# 2          0.008340            0.000060       0.00176      0.000015
# 3          0.010858            0.000183       0.00419      0.000046
# 4          0.008162            0.002669       0.00535      0.000044
#
#    rapJitter  ppq5Jitter  ddpJitter  locShimmer  locDbShimmer  apq3Shimmer  \
# 0    0.00067     0.00129    0.00200     0.05883         0.517      0.03011
# 1    0.00052     0.00112    0.00157     0.05516         0.502      0.02320
# 2    0.00057     0.00111    0.00171     0.09902         0.897      0.05094
# 3    0.00149     0.00268    0.00446     0.05451         0.527      0.02395
# 4    0.00166     0.00227    0.00499     0.05610         0.497      0.02909
#
#    apq5Shimmer  apq11Shimmer  ddaShimmer  meanAutoCorrHarmonicity  \
# 
ean_MFCC_8th_coef  mean_MFCC_9th_coef  mean_MFCC_10th_coef  \
# 0             0.61775            0.091821              0.54775
# 1             0.72944            0.236100              0.54722
# 2             0.51173            0.166150              0.79354
# 3             1.48370           -0.153650             -0.89378
# 4             1.54980           -0.202080             -1.03360
#
#    mean_MFCC_11th_coef  mean_MFCC_12th_coef  mean_delta_log_energy  \
# 0            -0.006825            -0.672740              -0.001013
# 1             0.057552            -0.395550              -0.001849
# 2             0.286980            -0.645550               0.001088
# 3            -0.754270             0.077452              -0.000720
# 4            -0.880070            -0.103460               0.001995
#
#    mean_0th_delta  mean_1st_delta  mean_2nd_delta  mean_3rd_delta  \
# 0       -0.000075       -0.003364       -0.000192        0.001357
# 1       -0.002700       -0.002639        0.002915       -0.001179
# 2       -0.008168        0.002542        0.007424       -0.001044
# 3       -0.007600        0.001532        0.000650        0.001284
# 4       -0.000891       -0.001809        0.004247       -0.000704
#
#    mean_4th_delta  mean_5th_delta  mean_6th_delta  mean_7th_delta  \
# 0       -0.000900       -0.003002        0.001548        0.005187
# 1       -0.000777        0.001994       -0.000110       -0.000650
# 2        0.000177       -0.000622        0.000619       -0.002684
# 3       -0.000516        0.001438        0.000310       -0.001449
# 4       -0.001753        0.000913        0.004485       -0.003392
#
#    mean_8th_delta  mean_9th_delta  mean_10th_delta  mean_11th_delta  \
# 0       -0.000205       -0.004737         0.002465         0.002514
# 1        0.002529       -0.000354        -0.002985         0.001452
# 2       -0.000304        0.003610         0.000217        -0.000004
# 3       -0.000706        0.000487        -0.002997        -0.000970
# 4       -0.001008        0.001829        -0.001250        -0.000751
#
#    mean_12th_delta  mean_delta_delta_log_energy  mean_delta_delta_0th  \
# 0        -0.001187                    -0.000179             -0.000828
# 1         0.002505                     0.000484             -0.000012
# 2        -0.000470                     0.000354              0.000057
# 3         0.001058                    -0.000112              0.000653
# 4        -0.001325                    -0.000211             -0.001466
#
#    mean_1st_delta_delta  mean_2nd_delta_delta  mean_3rd_delta_delta  \
# 0             -0.000498              0.001386              0.000173
# 1              0.001386             -0.000717             -0.001366
# 2              0.000333              0.000741             -0.000158
# 3             -0.001144              0.000094              0.000218
# 4              0.000946              0.000365             -0.000235
#
#    mean_4th_delta_delta  mean_5th_delta_delta  mean_6th_delta_delta  \
# 0             -0.000286              0.000428             -0.000044
# 1              0.000163             -0.000241             -0.000614
# 2             -0.000605              0.000025             -0.000567
# 3              0.000617             -0.000823              0.000195
# 4             -0.000170              0.000646             -0.000398
#
#    mean_7th_delta_delta  mean_8th_delta_delta  mean_9th_delta_delta  \
# 0             -0.000338              0.000430              0.000038
# 1             -0.000112             -0.000072              0.000252
# 2             -0.000400             -0.000037              0.000272
# 3              0.000263             -0.000232              0.000467
# 4              0.000256              0.000576             -0.000285
#
#    mean_10th_delta_delta  mean_11th_delta_delta  mean_12th_delta_delta  \
# 0              -0.000356              -0.000076               0.000027
# 1               0.000260               0.000691              -0.000109
# 2              -0.000032              -0.000166              -0.000298
# 3               0.000103              -0.000132              -0.000080
# 4               0.000177               0.000140               0.000035
#
#    std_Log_energy  std_MFCC_0th_coef  ...  tqwt_maxValue_dec_10  \
# 0         0.34158            1.02790  ...              0.025222
# 1         0.22994            0.92018  ...              0.063234
# 2         0.52574            0.92039  ...              0.011110
# 3         0.21182            1.07120  ...              0.117990
# 4         0.17405            0.81706  ...              0.072172
#
#    tqwt_maxValue_dec_11  tqwt_maxValue_dec_12  tqwt_maxValue_dec_13  \
# 0              0.022796              0.024286              0.048924
# 1              0.080975              0.099695              0.112210
# 2              0.013810              0.026241              0.039886
# 3              0.111290              0.122970              0.273530
# 4              0.086621              0.102950              0.235860
#
#    tqwt_maxValue_dec_14  tqwt_maxValue_dec_15  tqwt_maxValue_dec_16  \
# 0              0.105750               0.20486               0.29603
# 1              0.121580               0.18155               0.25945
# 2              0.081818               0.17028               0.20036
# 3              0.567740               0.83417               0.94236
# 4              0.567490               0.74186               0.75783
#
#    tqwt_maxValue_dec_17  tqwt_maxValue_dec_18  tqwt_maxValue_dec_19  \
# 0               0.46639               0.61778               0.59309
# 1               0.34292               0.50757               0.47634
# 2               0.28375               0.47225               0.43091
# 3               0.87739               0.76014               0.50019
# 4               0.80918               0.58794               0.44788
#
#    tqwt_maxValue_dec_20  tqwt_maxValue_dec_21  tqwt_maxValue_dec_22  \
# 0               0.32867               0.26301               0.44541
# 1               0.25345               0.19328               0.26291
# 2               0.23779               0.13881               0.12276
# 3               0.39757               0.55106               0.61714
# 4               0.46352               0.63134               0.55267
#
#    tqwt_maxValue_dec_23  tqwt_maxValue_dec_24  tqwt_maxValue_dec_25  \
# 0               0.66075               0.45846               0.24540
# 1               0.36756               0.29252               0.15110
# 2               0.17184               0.21641               0.24864
# 3               0.95174               2.13880               2.38800
# 4               1.04250               1.74970               2.28370
#
#    tqwt_maxValue_dec_26  tqwt_maxValue_dec_27  tqwt_maxValue_dec_28  \
# 0               0.45883               0.64375               0.39877
# 1               0.34059               0.50855               0.34973
# 2               0.25490               0.36358               0.26786
# 3               1.23460               0.59222               0.68665
# 4               1.35380               0.49868               0.57971
#
#    tqwt_maxValue_dec_29  tqwt_maxValue_dec_30  tqwt_maxValue_dec_31  \
# 0              0.056849              0.017824              0.014505
# 1              0.092360              0.055053              0.033916
# 2              0.074982              0.038477              0.029836
# 3              0.676480              0.486490              0.254560
# 4              0.623640              0.384470              0.189870
#
#    tqwt_maxValue_dec_32  tqwt_maxValue_dec_33  tqwt_maxValue_dec_34  \
# 0              0.008493              0.009728              0.006753
# 1              0.021793              0.017135              0.013696
# 2              0.020569              0.011885              0.009445
# 3              0.154360              0.133160              0.161530
# 4              0.206310              0.209420              0.135500
#
#    tqwt_maxValue_dec_35  tqwt_maxValue_dec_36  tqwt_skewnessValue_dec_1  \
# 0              0.006073             -0.009046                   0.86453
# 1              0.013895              0.028459                 -32.31440
# 2              0.008165             -0.002629                  -0.55520
# 3              0.120000              0.440710                   4.27060
# 4              0.092719              0.445130                   0.39147
#
#    tqwt_skewnessValue_dec_2  tqwt_skewnessValue_dec_3  \
# 0                  0.435380              1.110000e-15
# 1                -12.680900             -3.290000e-15
# 2                 -0.495120             -3.420000e-15
# 3                  0.616730              6.455000e-02
# 4                  0.032907             -4.187600e-03
#
#    tqwt_skewnessValue_dec_4  tqwt_skewnessValue_dec_5  \
# 0                  0.367450              0.000000e+00
# 1                 -7.259300             -3.830000e-15
# 2                 -1.354700             -4.930000e-15
# 3                  0.273230              2.917600e-02
# 4                  0.005982             -1.890000e-02
#
#    tqwt_skewnessValue_dec_6  tqwt_skewnessValue_dec_7  \
# 0                 -0.004310                 -0.005383
# 1                 -0.401950                 -0.101740
# 2                 -0.190220                 -0.040808
# 3                  0.179870                  0.156260
# 4                 -0.037698                 -0.114170
#
#    tqwt_skewnessValue_dec_8  tqwt_skewnessValue_dec_9  \
# 0             -1.110000e-17                 -0.000829
# 1              3.350000e-17                 -0.033633
# 2              7.430000e-17                 -0.016802
# 3             -1.866300e-02                 -0.014528
# 4             -1.775300e-02                 -0.009927
#
#    tqwt_skewnessValue_dec_10  tqwt_skewnessValue_dec_11  \
# 0                   0.001605                  -0.000362
# 1                  -0.024050                   0.178080
# 2                  -0.031809                  -0.006751
# 3                   0.051052                   0.022622
# 4                  -0.010845                   0.115230
#
#    tqwt_skewnessValue_dec_12  tqwt_skewnessValue_dec_13  \
# 0               1.010000e-15              -5.850000e-17
# 1              -3.680000e-15              -2.350000e-17
# 2               2.320000e-16              -7.030000e-17
# 3              -3.042800e-02               3.480400e-02
# 4               7.083800e-03               1.791500e-02
#
#    tqwt_skewnessValue_dec_14  tqwt_skewnessValue_dec_15  \
# 0                  -0.003143                   0.007433
# 1                   0.006114                  -0.000092
# 2                   0.006447                  -0.005623
# 3                   0.000153                   0.009561
# 4                   0.006910                  -0.005165
#
#    tqwt_skewnessValue_dec_16  tqwt_skewnessValue_dec_17  \
# 0               1.510000e-17               2.210000e-17
# 1              -7.090000e-18              -3.910000e-18
# 2              -1.960000e-16              -2.070000e-17
# 3               1.837600e-03               9.035600e-03
# 4              -4.920000e-03              -5.740400e-03
#
#    tqwt_skewnessValue_dec_18  tqwt_skewnessValue_dec_19  \
# 0              -9.370000e-18                   0.000734
# 1               8.750000e-18                   0.000330
# 2              -1.000000e-17                   0.004345
# 3               1.939000e-03                   0.052791
# 4              -3.680500e-03                  -0.017182
#
#    tqwt_skewnessValue_dec_20  tqwt_skewnessValue_dec_21  \
# 0              -4.330000e-18              -4.470000e-17
# 1              -9.330000e-19              -7.020000e-20
# 2              -8.020000e-18               1.200000e-16
# 3              -1.296300e-03              -1.281100e-03
# 4              -5.397100e-03               3.441400e-03
#
#    tqwt_skewnessValue_dec_22  tqwt_skewnessValue_dec_23  \
# 0              -1.390000e-17              -3.500000e-17
# 1              -1.010000e-17               1.520000e-17
# 2               4.890000e-17               3.920000e-17
# 3              -1.408200e-02              -1.239600e-03
# 4               1.298500e-03               3.069000e-03
#
#    tqwt_skewnessValue_dec_24  tqwt_skewnessValue_dec_25  \
# 0              -4.290000e-19              -9.660000e-18
# 1              -5.590000e-18               8.090000e-18
# 2               2.460000e-18               1.120000e-16
# 3               4.244100e-03               9.940000e-05
# 4               7.456300e-04               4.850000e-05
#
#    tqwt_skewnessValue_dec_26  tqwt_skewnessValue_dec_27  \
# 0              -1.660000e-17                   0.000115
# 1              -6.280000e-18                   0.000098
# 2              -1.140000e-17                   0.000402
# 3              -1.795500e-02                  -0.073310
# 4               5.015800e-02                   0.011784
#
#    tqwt_skewnessValue_dec_28  tqwt_skewnessValue_dec_29  \
# 0                  -0.102900                   0.030756
# 1                  -0.005679                  -0.205900
# 2                  -0.003824                   0.020236
# 3                   0.027619                   0.005381
# 4                   0.011756                  -0.008074
#
#    tqwt_skewnessValue_dec_30  tqwt_skewnessValue_dec_31  \
#
qwt_kurtosisValue_dec_30  tqwt_kurtosisValue_dec_31  \
# 0                     3.8686                     4.2105
# 1                    23.5155                    14.1962
# 2                     9.4959                    10.7458
# 3                     5.2558                    14.0403
# 4                     6.0805                     5.7621
#
#    tqwt_kurtosisValue_dec_32  tqwt_kurtosisValue_dec_33  \
# 0                     5.1221                     4.4625
# 1                    11.0261                     9.5082
# 2                    11.0177                     4.8066
# 3                     4.2235                     4.6857
# 4                     7.7817                    11.6891
#
#    tqwt_kurtosisValue_dec_34  tqwt_kurtosisValue_dec_35  \
# 0                     2.6202                     3.0004
# 1                     6.5245                     6.3431
# 2                     2.9199                     3.1495
# 3                     4.8460                     6.2650
# 4                     8.2103                     5.0559
#
#    tqwt_kurtosisValue_dec_36  class
# 0                    18.9405      1
# 1                    45.1780      1
# 2                     4.7666      1
# 3                     4.0603      1
# 4                     6.1164      1
#
# [5 rows x 755 columns]

# %% [markdown]
# #**Prepare Dataset for Machine Learning.**

# %%
df.dtypes.value_counts()
# Out:
# float64    749
# int64        6
# Name: count, dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #**Define X and y**

# %%
# Define target and cols to drop
target_col = 'class'
drop_cols = ['id']
# Define X and y
y = df[target_col].copy()
X = df.drop(columns=[target_col,*drop_cols]).copy()

# %% [markdown]
# #**Train Test Split**

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=321)
X_train.head()
# Out:
#      gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 48        0  0.83959  0.72967  0.52382        434               433
# 166       1  0.82163  0.80770  0.48638        325               324
# 101       1  0.83109  0.65411  0.40255        228               227
# 709       0  0.78915  0.78009  0.39191        356               355
# 215       1  0.76020  0.68983  0.40013        351               350
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  \
# 48           0.004456            0.000117       0.00145      0.000006
# 166          0.005941            0.000048       0.00105      0.000006
# 101          0.008480            0.000117       0.00127      0.000011
# 709          0.005435            0.000077       0.00122      0.000007
# 215          0.005500            0.000070       0.00149      0.000008
#
#      rapJitter  ppq5Jitter  ddpJitter  locShimmer  locDbShimmer  apq3Shimmer  \
# 48     0.00020     0.00050    0.00061     0.13146         1.134      0.06489
# 166    0.00022     0.00051    0.00066     0.05181         0.490      0.02440
# 101    0.00027     0.00065    0.00080     0.01522         0.132      0.00779
# 709    0.00014     0.00037    0.00043     0.03620         0.318      0.01568
# 215    0.00018     0.00048    0.00053     0.02526         0.237      0.01162
#
#      apq5Shimmer  apq11Shimmer  ddaShimmer  meanAutoCorrHarmonicity  \
# 48       0.08648       0.10384     0.19467                 0.937850
# 166      0.03243       0.04805     0.07320                 0.991289
# 101      0.01035       0.01325     0.02337                 0.996459
# 709      0.02208       0.03653     0.04704                 0.997318
# 215      0.01409       0.02299     0.03487                 0.991590
#
#      meanNoiseToHarmHarmonicity  meanHarmToNoiseHarmonicity  minIntensity  \
# 48                     0.073649                      13.225     71.835180
# 166                    0.008833                      22.514     51.983613
# 101                    0.003564                      26.512     77.048555
# 709                    0.002691                      26.597     75.353124
# 215                    0.008552                      22.208     72.390030
#
#      maxIntensity  meanIntensity          f1           f2           f3  \
# 48      80.474516      75.788252  682.183602  1209.085895  3109.349391
# 166     60.251655      56.655472  446.745042  1246.391096  2212.983322
# 101     78.538938      77.965981  601.913542  1120.170460  2459.394884
# 709     78.564838      77.151144  641.444647  1387.234348  2508.667739
# 215     82.945043      80.142927  639.809589  1123.530675  2981.735692
#
#               f4          b1          b2          b3           b4  GQ_prc5_95  \
# 48   3861.584625   61.842771  733.778887  176.925396   176.282517     1.00000
# 166  3130.831238  187.478554  113.864703  184.299008    45.586893     0.58347
# 101  3607.996329   54.720308   88.378818  354.244468   120.260666     0.79532
# 709  4063.006887  567.062248  366.549689  278.293654    62.785426     1.00000
# 215  4029.997965  477.828188  238.817864   97.805702  1400.991832     1.00000
#
#      GQ_std_cycle_open  GQ_std_cycle_closed  GNE_mean  GNE_std  GNE_SNR_TKEO  \
# 48             17.6127               0.0000    0.9989  0.22754       0.19263
# 166            52.2607              27.8889    1.3612  0.43542       0.11666
# 101            17.9323               2.2975    0.9236  0.11056       0.23885
# 709             8.0920               0.0000    1.0164  0.17925       0.13011
# 215            10.1326               0.0000    1.1939  0.35747       0.11777
#
#       GNE_SNR_SEO  GNE_NSR_TKEO  GNE_NSR_SEO  VFER_mean  VFER_std  \
# 48   2.198560e+06        1.7305       3.0195   0.001208  0.001277
# 166  8.168449e+05        1.5832       2.9549   0.000947  0.001665
# 101  1.670755e+06        1.7574       2.9948   0.000556  0.000354
# 709  2.003808e+06        1.6225       3.0508   0.000083  0.000152
# 215  1.739332e+06        1.6098       3.0464   0.000835  0.000554
#
#      VFER_entropy  VFER_SNR_TKEO  VFER_SNR_SEO  VFER_NSR_TKEO  VFER_NSR_SEO  \
# 48        3.29150        84.1572      311.2177         1.2258        1.2964
# 166       1.93350       213.8858      117.0721         1.2563        1.1821
# 101       0.93884       408.3252      199.4683         1.3362        1.2512
# 709       0.26684         5.6811       20.4048         1.0864        1.1219
# 215       2.02450        80.2887      161.7936         1.2235        1.2717
#
#      IMF_SNR_SEO  IMF_SNR_TKEO  IMF_SNR_entropy  IMF_NSR_SEO  IMF_NSR_TKEO  \
# 48       26.9116       2.03540          16.8896      0.27880        9.4355
# 166       5.6717       0.62171           3.3192      0.28887       33.4759
# 101       7.9082       2.15050           6.9176      0.18293       20.4305
# 709      96.2568       2.41290          19.6462      0.20577        6.9838
# 215      11.9748       2.51810           8.2646      0.20093       11.4303
#
#      IMF_NSR_entropy  mean_Log_energy  mean_MFCC_0th_coef  mean_MFCC_1st_coef  \
# 48           0.21923           9.5048             14.0908              4.4359
# 166          0.22764           9.8284              7.7368             10.8203
# 101          0.16218          10.2422             14.2761              8.0900
# 709          0.17237           9.9100             15.7881              6.7137
# 215          0.17819          10.0993             15.8435              6.0767
#
#      mean_MFCC_2nd_coef  mean_MFCC_3rd_coef  mean_MFCC_4th_coef  \
# 48              2.57560             2.20980            -1.57330
# 166             3.04920            -0.87766             0.85818
# 101             2.53660             1.01510            -1.75350
# 709             0.85811             0.77836            -1.81190
# 215             1.93300             0.78430            -1.46110
#
#      mean_MFCC_5th_coef  mean_MFCC_6th_coef  mean_MFCC_7th_coef  \
# 48             -0.75228           -2.224000            1.167500
# 166             0.70070           -0.681800           -0.859590
# 101            -1.90130           -1.158000            0.517280
# 709            -0.31226           -0.045048           -0.085106
# 215            -2.03070           -2.039500            0.711370
#
#      mean_MFCC_8th_coef  mean_MFCC_9th_coef  mean_MFCC_10th_coef  \
# 48             0.896800           -0.037773              0.47052
# 166            0.158740           -0.314940             -1.17490
# 101            0.100860            0.775500              0.37188
# 709            0.073222           -0.954750             -0.28238
# 215            0.217410           -0.316480             -0.38978
#
#      mean_MFCC_11th_coef  mean_MFCC_12th_coef  mean_delta_log_energy  \
# 48              -0.49166              0.14519              -0.010172
# 166             -0.68424              0.56442              -0.005394
# 101             -0.97381              0.42465              -0.000395
# 709              0.30664             -1.20970              -0.001269
# 215             -0.79593             -0.41019              -0.005310
#
#      mean_0th_delta  mean_1st_delta  mean_2nd_delta  mean_3rd_delta  \
# 48        -0.034459        0.003935        0.006906        0.002867
# 166       -0.011614        0.002062       -0.000611       -0.001132
# 101       -0.001682        0.001756       -0.002911        0.001303
# 709        0.001302        0.000154       -0.008705        0.002873
# 215       -0.006926        0.000486       -0.004747        0.005268
#
#      mean_4th_delta  mean_5th_delta  mean_6th_delta  mean_7th_delta  \
# 48         0.006881        0.002495        0.004055        0.000126
# 166       -0.001793       -0.002862       -0.003719       -0.001923
# 101        0.001523        0.003130       -0.002107       -0.002969
# 709        0.002170        0.000062       -0.000019       -0.000183
# 215        0.002696       -0.001246        0.003390        0.003824
#
#      mean_8th_delta  mean_9th_delta  mean_10th_delta  mean_11th_delta  \
# 48         0.005811        0.009589        -0.000532         0.001722
# 166        0.000403        0.001350         0.002024         0.001697
# 101        0.002027       -0.000573         0.000823         0.003432
# 709        0.002548       -0.001348        -0.001687         0.003100
# 215        0.001898       -0.002528        -0.001662        -0.000212
#
#      mean_12th_delta  mean_delta_delta_log_energy  mean_delta_delta_0th  \
# 48          0.002253                    -0.000067             -0.000242
# 166        -0.000225                     0.000299              0.002542
# 101        -0.004677                    -0.000017             -0.001154
# 709        -0.001961                     0.000064              0.000513
# 215        -0.000214                    -0.000018              0.000091
#
#      mean_1st_delta_delta  mean_2nd_delta_delta  mean_3rd_delta_delta  \
# 48              -0.000550             -0.000604             -0.000054
# 166             -0.002441              0.000403              0.001303
# 101              0.000701              0.000040              0.000599
# 709             -0.000693              0.000693             -0.000416
# 215             -0.000018             -0.000015             -0.000100
#
#      mean_4th_delta_delta  mean_5th_delta_delta  mean_6th_delta_delta  \
# 48               0.001015              0.000918             -0.000043
# 166             -0.000226             -0.000239             -0.000019
# 101             -0.000847              0.000446             -0.000082
# 709              0.000527             -0.000402              0.000167
# 215             -0.000067              0.000492             -0.000065
#
#      mean_7th_delta_delta  mean_8th_delta_delta  mean_9th_delta_delta  \
# 48              -0.001366              0.000372             -0.000028
# 166             -0.000384             -0.000569              0.000099
# 101             -0.000068             -0.000031              0.000646
# 709             -0.000087             -0.000216              0.000402
# 215             -0.000215             -0.000157              0.000092
#
#      mean_10th_delta_delta  mean_11th_delta_delta  mean_12th_delta_delta  \
# 48               -0.000287               0.000500               0.000450
# 166               0.000460              -0.000279              -0.000433
# 101              -0.000952               0.000198               0.000431
# 709              -0.000051              -0.000335               0.000293
# 215               0.000438               0.000071               0.000312
#
#      std_Log_energy  std_MFCC_0th_coef  std_MFCC_1st_coef  ...  \
# 48         0.415500            1.37810            0.42233  ...
# 166        0.434510            2.10700            1.74420  ...
# 101        0.069329            0.79237            0.69370  ...
# 709        0.156190            0.55993            0.38497  ...
# 215        0.516490            0.91517            0.55787  ...
#
#      tqwt_maxValue_dec_9  tqwt_maxValue_dec_10  tqwt_maxValue_dec_11  \
# 48              0.052472              0.034283              0.031181
# 166             0.002705              0.002784              0.002814
# 101             0.122760              0.140070              0.162820
# 709             0.076852              0.096764              0.123340
# 215             0.113030              0.110310              0.118710
#
#      tqwt_maxValue_dec_12  tqwt_maxValue_dec_13  tqwt_maxValue_dec_14  \
# 48               0.082058              0.247310              0.539320
# 166              0.004988              0.009283              0.011431
# 101              0.174850              0.228820              0.281560
# 709              0.178020              0.235920              0.290690
# 215              0.139060              0.142350              0.343600
#
#      tqwt_maxValue_dec_15  tqwt_maxValue_dec_16  tqwt_maxValue_dec_17  \
# 48               0.728260              0.743760              0.895850
# 166              0.009803              0.011675              0.026667
# 101              0.402350              0.541940              0.761850
# 709              0.316680              0.396440              0.521240
# 215              0.638830              0.926880              1.246000
#
#      tqwt_maxValue_dec_18  tqwt_maxValue_dec_19  tqwt_maxValue_dec_20  \
# 48                0.91244              0.718040              0.564520
# 166               0.04355              0.051916              0.055245
# 101               1.18290              1.038100              0.637650
# 709               0.59930              0.645020              0.512340
# 215               1.38500              1.036700              0.943290
#
#      tqwt_maxValue_dec_21  tqwt_maxValue_dec_22  tqwt_maxValue_dec_23  \
# 48               0.435740              0.384700              0.283570
# 166              0.063188              0.068003              0.079904
# 101              0.454180              0.412560              0.438550
# 709              0.488370              0.358670              0.595990
# 215              0.812430              0.577650              0.439360
#
#      tqwt_maxValue_dec_24  tqwt_maxValue_dec_25  tqwt_maxValue_dec_26  \
# 48                0.58886               0.73467               0.54966
# 166               0.11185               0.20470               0.17449
# 101               0.43735               0.27192               0.53657
# 709               1.32680               1.70510               0.87913
# 215               1.03170               1.31810               0.73026
#
#      tqwt_maxValue_dec_27  tqwt_maxValue_dec_28  tqwt_maxValue_dec_29  \
# 48               0.161980              0.131630              0.078937
# 166              0.051467              0.017417              0.010131
# 101              0.842470              0.719510              0.168920
# 709              0.171530              0.102840              0.087582
# 215              0.338530              0.230670              0.177900
#
#      tqwt_maxValue_dec_30  tqwt_maxValue_dec_31  tqwt_maxValue_dec_32  \
# 48               0.073003              0.102580              0.103570
# 166              0.007780              0.006227              0.004726
# 101              0.041618              0.051863              0.037426
# 709              0.122830              0.101880              0.144750
# 215              0.157890              0.140470              0.119750
#
#      tqwt_maxValue_dec_33  tqwt_maxValue_dec_34  tqwt_maxValue_dec_35  \
# 48               0.054633              0.031247              0.039070
# 166              0.003120              0.002346              0.002835
# 101              0.039225              0.057087              0.056773
# 709              0.164050              0.281680              0.279910
# 215              0.105680              0.096800              0.089990
#
#      tqwt_maxValue_dec_36  tqwt_skewnessValue_dec_1  tqwt_skewnessValue_dec_2  \
# 48               0.111400                  0.010706                  0.039246
# 166              0.007134                -58.029600                -22.031300
# 101              0.110320                 35.588700                  3.002600
# 709              0.408460                  4.242700                  0.259240
# 215              0.219260                  3.276400                  0.178270
#
#      tqwt_skewnessValue_dec_3  tqwt_skewnessValue_dec_4  \
# 48              -1.482700e-02                 -0.033479
# 166              1.830000e-15                 -8.744200
# 101             -2.229300e-01                  1.739200
# 709              4.344000e-02                  0.003402
# 215              6.540000e-16                  0.074640
#
#      tqwt_skewnessValue_dec_5  tqwt_skewnessValue_dec_6  \
# 48              -2.993800e-02                  0.001292
# 166             -4.240000e-15                  1.385300
# 101             -3.407500e-02                  0.251080
# 709             -1.829100e-02                  0.031245
# 215              3.240000e-17                  0.017858
#
#      tqwt_skewnessValue_dec_7  tqwt_skewnessValue_dec_8  \
# 48                   0.001838             -1.892200e-02
# 166                  0.286620             -8.920000e-16
# 101                  0.560520             -8.466700e-02
# 709                  0.007392              3.216000e-03
# 215                 -0.003029             -6.530000e-18
#
#      tqwt_skewnessValue_dec_9  tqwt_skewnessValue_dec_10  \
# 48                   0.015927                   0.028082
# 166                  0.054393                  -0.004095
# 101                  0.444520                   0.183410
# 709                  0.000127                   0.022529
# 215                  0.031144                  -0.037394
#
#      tqwt_skewnessValue_dec_11  tqwt_skewnessValue_dec_12  \
# 48                    0.023133              -1.588300e-02
# 166                  -0.023989              -4.660000e-17
# 101                   0.328700              -1.553400e-02
# 709                   0.019174               1.120300e-02
# 215                  -0.214100               7.050000e-17
#
#      tqwt_skewnessValue_dec_13  tqwt_skewnessValue_dec_14  \
# 48                3.450000e-05                   0.005734
# 166               2.110000e-18                  -0.000892
# 101               1.221400e-03                  -0.007817
# 709               3.535300e-03                   0.001035
# 215              -1.600000e-17                  -0.000675
#
#      tqwt_skewnessValue_dec_15  tqwt_skewnessValue_dec_16  \
# 48                    0.001436              -1.006800e-03
# 166                   0.006865               6.960000e-18
# 101                  -0.010950               2.513900e-02
# 709                  -0.007002               1.593600e-03
# 215                   0.005017              -5.930000e-18
#
#      tqwt_skewnessValue_dec_17  tqwt_skewnessValue_dec_18  \
# 48                1.182200e-03              -5.670200e-03
# 166               5.860000e-18               6.080000e-18
# 101               4.841600e-04              -3.304400e-04
# 709               6.001700e-03              -2.306100e-04
# 215              -1.030000e-17              -2.880000e-17
#
#      tqwt_skewnessValue_dec_19  tqwt_skewnessValue_dec_20  \
# 48                    0.003241              -3.184200e-04
# 166                  -0.001418              -1.520000e-17
# 101                  -0.002116               1.031200e-02
# 709                   0.000695              -1.953600e-03
# 215                   0.000209              -1.070000e-18
#
#      tqwt_skewnessValue_dec_21  tqwt_skewnessValue_dec_22  \
# 48                5.959200e-04              -1.812000e-03
# 166               3.010000e-17              -2.320000e-18
# 101               1.085300e-03               2.362900e-03
# 709               1.593400e-04               2.438100e-02
# 215               7.010000e-17              -5.670000e-18
#
#      tqwt_skewnessValue_dec_23  tqwt_skewnessValue_dec_24  \
# 48                3.253000e-03               1.097700e-03
# 166              -3.780000e-17               1.750000e-17
# 101               3.471100e-04              -1.375300e-03
# 709               1.753400e-03              -3.341700e-04
# 215               1.490000e-17              -2.880000e-18
#
#      tqwt_skewnessValue_dec_25  tqwt_skewnessValue_dec_26  \
# 48                1.965500e-04              -2.289200e-02
# 166               2.000000e-18               4.310000e-17
# 101              -7.780000e-03              -2.583500e-03
# 709              -3.970000e-05               2.300300e-02
# 215              -4.080000e-20               1.010000e-17
#
#      tqwt_skewnessValue_dec_27  tqwt_skewnessValue_dec_28  \
# 48                   -0.577710                   -0.22098
# 166                   0.020711                   -0.06462
# 101                  -0.000101                    0.00132
# 709                  -0.997550                   -2.59100
# 215                   0.183470                    2.27660
#
#      tqwt_skewnessValue_dec_29  tqwt_skewnessValue_dec_30  \
# 48                   -0.037480              -3.732100e-03
# 166                   0.072316               1.960000e-17
# 101                   0.018161              -2.160100e+00
# 709                  -1.775100               2.421400e-02
# 215                   3.601900              -3.260000e-15
#
#      tqwt_skewnessValue_dec_31  tqwt_skewnessValue_dec_32  \
# 48                   -0.031565                  -0.055910
# 166                   0.202910                   0.007799
# 101                   0.470380                   0.089470
# 709                  -0.350310                  -0.117900
# 215                   3.543400                   3.507200
#
#      tqwt_skewnessValue_dec_33  tqwt_skewnessValue_dec_34  \
# 48                   -0.294980                  -0.020332
# 166                   0.038660                   0.519720
# 101                   0.236530                   0.091478
# 709                   0.030697                  -0.082280
# 215                   3.739900                   3.446000
#
#      tqwt_skewnessValue_dec_35  tqwt_skewnessValue_dec_36  \
# 48                   -0.140560                   -0.18120
# 166                   0.597210                    5.06860
# 101                   0.034112                    0.22048
# 709                   0.129880                    0.19359
# 215                   3.321000                    8.92610
#
#      tqwt_kurtosisValue_dec_1  tqwt_kurtosisValue_dec_2  \
# 215                     1.5779                     1.6230
#
#      tqwt_kurtosisValue_dec_27  tqwt_kurtosisValue_dec_28  \
# 48                      8.0473                     7.9435
# 166                     2.3436                     8.1714
# 101                     1.6287                     1.6705
# 709                    26.3886                    55.5132
# 215                    48.9100                    68.7127
#
#      tqwt_kurtosisValue_dec_29  tqwt_kurtosisValue_dec_30  \
# 48                      2.7276                     2.6472
# 166                     4.2304                     3.2091
# 101                     2.0567                    48.0479
# 709                    32.9777                    11.4057
# 215                    67.7104                    68.9546
#
#      tqwt_kurtosisValue_dec_31  tqwt_kurtosisValue_dec_32  \
# 48                      2.9677                     3.1993
# 166                     2.9387                     2.7929
# 101                    10.2197                     3.7186
# 709                     6.4028                     6.5222
# 215                    67.1374                    57.9764
#
#      tqwt_kurtosisValue_dec_33  tqwt_kurtosisValue_dec_34  \
# 48                      3.9941                     2.9685
# 166                     2.7278                     3.7322
# 101                     3.1749                     4.0824
# 709                     7.2956                     9.4350
# 215                    54.6061                    51.7438
#
#      tqwt_kurtosisValue_dec_35  tqwt_kurtosisValue_dec_36
# 48                      3.1846                     3.6894
# 166                     6.9761                    44.1335
# 101                     3.7854                     4.5031
# 709                     7.1035                     4.8100
# 215                    46.8636                    93.8852
#
# [5 rows x 753 columns]

# %% [markdown]
# #**Scale Data**

# %%
# Instantiate Standard Scaler
scaler = StandardScaler()
# Fit & transform data.
X_train_tf = scaler.fit_transform(X_train)
X_test_tf = scaler.transform(X_test)

# %% [markdown]
# #**Check for Class Balance**

# %%
# Check for class balance of target
y_train.value_counts(1)
# Out:
# class
# 1    0.753086
# 0    0.246914
# Name: proportion, dtype: float64

# %%
from imblearn.over_sampling import SMOTE,SMOTENC
smote = SMOTE()
X_train_sm, y_train_sm = smote.fit_resample(X_train_tf, y_train)
y_train_sm.value_counts()
# Out:
# class
# 1    427
# 0    427
# Name: count, dtype: int64

# %% [markdown]
# #**Time a model without PCA**

# %%
# Import datetime library
import datetime as dt

# Record the start time
start = dt.datetime.now()

clf = RandomForestClassifier(random_state=42)

clf.fit(X_train_sm, y_train_sm)

# Record the end time and calc duration
end = dt.datetime.now()
dur_baseline = end-start

evaluate_classification(clf, X_train_sm,y_train_sm, X_test_tf, y_test)
print(f'Training time was: {dur_baseline}')
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       427
#            1       1.00      1.00      1.00       427
#
#     accuracy                           1.00       854
#    macro avg       1.00      1.00      1.00       854
# weighted avg       1.00      1.00      1.00       854
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.72      0.65      0.69        52
#            1       0.87      0.91      0.89       137
#
#     accuracy                           0.84       189
#    macro avg       0.80      0.78      0.79       189
# weighted avg       0.83      0.84      0.83       189
# Training time was: 0:00:04.403815

# %% [markdown]
# #**PCA**

# %%
# Instantiate & fit data using PCA
pca = PCA(n_components=3)
X_train_pca = pca.fit_transform(X_train_sm)
X_test_pca = pca.transform(X_test_tf)
X_train_pca.head()
# Out:
#         pca0       pca1       pca2
# 0  -5.199239   0.320460   1.997406
# 1  12.105720 -17.286448   5.092850
# 2   8.054773   0.524567 -10.395157
# 3   0.041639   1.213431  -2.721379
# 4  -1.572405   1.557231  -7.520636

# %% [markdown]
# #**Time a model with 3 PCs**

# %%
# Record the start time
start = dt.datetime.now()

clf = RandomForestClassifier(random_state=42)
clf.fit(X_train_pca, y_train_sm)

# Record the end time and calc duration
end = dt.datetime.now()
dur_pca = end-start

evaluate_classification(clf, X_train_pca,y_train_sm, X_test_pca, y_test)
print(f'Training time was: {dur_pca}')
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       427
#            1       1.00      1.00      1.00       427
#
#     accuracy                           1.00       854
#    macro avg       1.00      1.00      1.00       854
# weighted avg       1.00      1.00      1.00       854
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.56      0.65      0.60        52
#            1       0.86      0.80      0.83       137
#
#     accuracy                           0.76       189
#    macro avg       0.71      0.73      0.72       189
# weighted avg       0.78      0.76      0.77       189
# Training time was: 0:00:00.446251

# %%
# Compare speeds before and after PCA
compare_speed = dur_baseline/dur_pca
print(f"Using PCs was {compare_speed:.2f} times faster!")
# Out:
# Using PCs was 9.87 times faster!

# %% [markdown]
# #**Choosing the Number of Components to Return**

# %%
# Initialize and fit PCA
pca = PCA()
pca.fit(X_train_sm, y_train)
# Out:
# PCA()

# %%
# Determine how much variance is explained by each PC
explained = pd.Series(pca.explained_variance_ratio_, name='Explained Variance Ratio')
explained
# Out:
# 0      1.496232e-01
# 1      9.639294e-02
# 2      8.897993e-02
# 3      5.250038e-02
# 4      4.020520e-02
#            ...
# 748    7.158847e-34
# 749    7.158847e-34
# 750    7.158847e-34
# 751    7.158847e-34
# 752    7.158847e-34
# Name: Explained Variance Ratio, Length: 753, dtype: float64

# %%
# plot the cumulative sum of the percentage of explained variance for each component and those before it.
ax = explained.cumsum().plot(marker='.')
# add a line to mark .9 (or 90%) variance explained
ax.axhline(.9, color='k');

# %% [markdown]
# #**Specifying the Explained Variance**

# %%
# Define PCA to address 85% of the variance
pca85 = PCA(n_components=.85)
# fit and transform on training data
X_train_pca85 = pca85.fit_transform(X_train_sm)
# transform test data
X_test_pca85 = pca85.transform(X_test_tf)
# obtain the number of PCs used
pca85.n_components_
# Out:
# np.int64(69)

# %% [markdown]
# #**Timing when 85% of Variance is Explained with PCSs**

# %%
# Record the start time
start = dt.datetime.now()

clf = RandomForestClassifier(random_state=42)
clf.fit(X_train_pca85, y_train_sm)

# Record the end time and calc duration
end = dt.datetime.now()
dur_pca_85 = end-start

evaluate_classification(clf, X_train_pca85,y_train_sm, X_test_pca85, y_test)
print(f'Training time was: {dur_pca_85}')
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       427
#            1       1.00      1.00      1.00       427
#
#     accuracy                           1.00       854
#    macro avg       1.00      1.00      1.00       854
# weighted avg       1.00      1.00      1.00       854
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.71      0.62      0.66        52
#            1       0.86      0.91      0.88       137
#
#     accuracy                           0.83       189
#    macro avg       0.79      0.76      0.77       189
# weighted avg       0.82      0.83      0.82       189
# Training time was: 0:00:01.667648

# %%
compare_speed = dur_baseline/dur_pca_85
print(f"Using PC's with .85 was {compare_speed:.2f} times faster!")
# Out:
# Using PC's with .85 was 2.64 times faster!

# %% [markdown]
# ![Screenshot (2312).png](data:image/png;base64,...)
