# %% [markdown]
# <a href="https://colab.research.google.com/github/dohaalnabahin/Data_science_and_machine_learning_Journey/blob/main/while_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# define the initial value of i
# set the while condition (we want the loop to repeat while this condition is still True)
# indicate what the loop will do
# print each iteration
i = 0
while i<5:
  i += 1
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 0
while i<5:
  i += 1
print(i)
# Out:
# 5
