# %% [markdown]
# <a href="https://colab.research.google.com/github/dohaalnabahin/Data_science_and_machine_learning_Journey/blob/main/Moving_Average_(MA)_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Imports**

# %%
pip install pmdarima

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.tsa.api as tsa
from pmdarima.arima.utils import ndiffs
from pmdarima.model_selection import train_test_split

# %% [markdown]
# #**Custom Functions**

# %%
def plot_forecast(ts_train, ts_test, forecast_df, n_train_lags=None,
                  figsize=(10,4), title='Comparing Forecast vs. True Data'):
    ### PLot training data, and forecast (with upper/,lower ci)
    fig, ax = plt.subplots(figsize=figsize)
    # setting the number of train lags to plot if not specified
    if n_train_lags==None:
        n_train_lags = len(ts_train)

    # Plotting Training  and test data
    ts_train.iloc[-n_train_lags:].plot(ax=ax, label="train")
    ts_test.plot(label="test", ax=ax)
    # Plot forecast
    forecast_df['mean'].plot(ax=ax, color='green', label="forecast")
    # Add the shaded confidence interval
    ax.fill_between(forecast_df.index,
                    forecast_df['mean_ci_lower'],
                   forecast_df['mean_ci_upper'],
                   color='green', alpha=0.3,  lw=2)
    # set the title and add legend
    ax.set_title(title)
    ax.legend();

    return fig, ax

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
def regression_metrics_ts(ts_true, ts_pred, label="", verbose=True, output_dict=False,):
    # Get metrics
    mae = mean_absolute_error(ts_true, ts_pred)
    mse = mean_squared_error(ts_true, ts_pred)
    rmse = mean_squared_error(ts_true, ts_pred, squared=False)
    r_squared = r2_score(ts_true, ts_pred)
    mae_perc = mean_absolute_percentage_error(ts_true, ts_pred) * 100
    if verbose == True:
        # Print Result with label
        header = "---" * 20
        print(header, f"Regression Metrics: {label}", header, sep="\n")
        print(f"- MAE = {mae:,.3f}")
        print(f"- MSE = {mse:,.3f}")
        print(f"- RMSE = {rmse:,.3f}")
        print(f"- R^2 = {r_squared:,.3f}")
        print(f"- MAPE = {mae_perc:,.2f}%")
    if output_dict == True:
        metrics = {
            "Label": label,
            "MAE": mae,
            "MSE": mse,
            "RMSE": rmse,
            "R^2": r_squared,
            "MAPE(%)": mae_perc,
        }
        return metrics

# %%
# Custom function for Ad Fuller Test
def get_adfuller_results(ts, alpha=.05, label='adfuller', **kwargs): #kwargs for adfuller()
    # Saving each output
    (test_stat, pval, nlags, nobs, crit_vals_d,
    icbest ) = tsa.adfuller(ts, **kwargs)
    # Converting output to a dictionary with the interpretation of p
    adfuller_results = {'Test Statistic': test_stat,
                        "# of Lags Used":nlags,
                       '# of Observations':nobs,
                        'p-value': round(pval,6),
                        'alpha': alpha,
                       'sig/stationary?': pval < alpha}
    return pd.DataFrame(adfuller_results, index =[label])

# %% [markdown]
# #**Load & Prepare the Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load in data
ts = pd.read_csv('/content/drive/MyDrive/AXSOSACADEMY/05-IntermediateML/MA_lesson_ts.csv', index_col = 'date')
ts.head()
# Out:
#                value
# date
# 2000-01-31  0.332798
# 2000-02-29  0.057122
# 2000-03-31  0.691783
# 2000-04-30  1.132335
# 2000-05-31  0.692867

# %%
# We have monthly data so we will set our frequency to M
ts.index.freq= "M"
# Define the series
ts = ts['value']

# %%
# Check for nulls
ts.isna().sum()
# Out:
# np.int64(0)

# %%
# Plot the time series
ts.plot();

# %%
# Make acf plot of raw data to look for seasonality
tsa.graphics.plot_acf(ts);

# %% [markdown]
# #**Check for stationarity**

# %%
# Call custom function to check to see if data is stationary
get_adfuller_results(ts)
# Out:
#           Test Statistic  # of Lags Used  # of Observations   p-value  alpha  \
# adfuller       -4.254855               9                190  0.000531   0.05
#
#           sig/stationary?
# adfuller             True

# %%
# check differencing with ndiffs
d = ndiffs(ts)
print (f'd = {d}')
# Out:
# d = 0

# %% [markdown]
# #**Determining the MA Order Using Autocorrelation**

# %%
### NEW FUNCTION FOR COMBINED ACF/PACF WITH ANNOTATIONS
def plot_acf_pacf(ts, nlags=40, figsize=(10, 5),
                  annotate_sig=False, alpha=.05,
                 acf_kws={}, pacf_kws={},
                  annotate_seas=False, m = None,
                 seas_color='black'):

    fig, axes = plt.subplots(nrows=2, figsize=figsize)

    # Sig lags line style
    sig_vline_kwargs = dict( ls=':', lw=1, zorder=0, color='red')
    # ACF
    tsa.graphics.plot_acf(ts, ax=axes[0], lags=nlags, **acf_kws)

    ## Annotating sig acf lags
    if annotate_sig == True:
        sig_acf_lags = get_sig_lags(ts,nlags=nlags,alpha=alpha, type='ACF')
        for lag in sig_acf_lags:
            axes[0].axvline(lag,label='sig', **sig_vline_kwargs )
    # PACF
    tsa.graphics.plot_pacf(ts,ax=axes[1], lags=nlags, **pacf_kws)

    ## Annotating sig pacf lags
    if annotate_sig == True:
        ## ANNOTATING SIG LAGS
        sig_pacf_lags = get_sig_lags(ts,nlags=nlags,alpha=alpha, type='PACF')
        for lag in sig_pacf_lags:
            axes[1].axvline(lag, label='sig', **sig_vline_kwargs)

    ### ANNOTATE SEASONS
    if annotate_seas == True:
        # Ensure m was defined
        if m is None:
            raise Exception("Must define value of m if annotate_seas=True.")
        ## Calculate number of complete seasons to annotate
        n_seasons = nlags//m
        # Seasonal Lines style
        seas_vline_kwargs = dict( ls='--',lw=1, alpha=.7, color=seas_color, zorder=-1)

        ## for each season, add a line
        for i in range(1, n_seasons+1):
            axes[0].axvline(m*i, **seas_vline_kwargs, label="season")
            axes[1].axvline(m*i, **seas_vline_kwargs, label="season")
    fig.tight_layout()

    return fig

# %%
# Let's call our custom acf/pacf plot on our stationary (d = 0) data
plot_acf_pacf(ts);

# %% [markdown]
# #**Train Test Split**

# %%
# tts
train, test = train_test_split(ts, test_size=.20)
# Visualize the train and test data
ax = train.plot(label='Train')
test.plot(ax=ax, label='Test')
ax.legend();

# %% [markdown]
# #**MA-only Model**

# %%
# First define the orders (p,d,q)
p = 0 # p is us ed for AR models (set to 0 for an MA only model)
d = 0 # no differcing was required to make the data stationary
q = 2 # q based on significant lags in ACF
# Now instantiate the model with the data and fit
ma_2_model = tsa.ARIMA(train, order = (p,d,q)).fit()
ma_2_model
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)

# %%
# Obtain the parameters of the fit model
ma_2_model.params
# Out:
# const    -0.105130
# ma.L1     0.446952
# ma.L2     0.946894
# sigma2    0.379158
# dtype: float64

# %%
forecast_df = ma_2_model.get_forecast(steps=len(test)).summary_frame()

forecast_df.index = test.index

plot_forecast(train, test, forecast_df)
# Out:
# (<Figure size 1000x400 with 1 Axes>,
#  <Axes: title={'center': 'Comparing Forecast vs. True Data'}, xlabel='date'>)

# %% [markdown]
# #**Combining AR & MA models**

# %%
# Load in data
ts = pd.read_csv('/content/drive/MyDrive/AXSOSACADEMY/05-IntermediateML/AR_MA_lesson_ts.csv', parse_dates = ['date'], index_col = 'date')
ts.head()
# Out:
#                value
# date
# 2022-05-25 -0.148001
# 2022-05-26 -0.187799
# 2022-05-27 -0.034606
# 2022-05-28  0.304207
# 2022-05-29  0.228702

# %%
# We have daily data so we will set our frequency to D
ts.index.freq= "D"
ts.index
# Out:
# DatetimeIndex(['2022-05-25', '2022-05-26', '2022-05-27', '2022-05-28',
#                '2022-05-29', '2022-05-30', '2022-05-31', '2022-06-01',
#                '2022-06-02', '2022-06-03',
#                ...
#                '2022-12-01', '2022-12-02', '2022-12-03', '2022-12-04',
#                '2022-12-05', '2022-12-06', '2022-12-07', '2022-12-08',
#                '2022-12-09', '2022-12-10'],
#               dtype='datetime64[ns]', name='date', length=200, freq='D')

# %%
# Check for nulls
ts.isna().sum().sum()
# Out:
# np.int64(0)

# %%
# Plot the time series
ts.plot();

# %%
# Call custom function to check to see if data is stationary
get_adfuller_results(ts)
# Out:
#           Test Statistic  # of Lags Used  # of Observations   p-value  alpha  \
# adfuller       -2.258272               1                198  0.185779   0.05
#
#           sig/stationary?
# adfuller            False

# %%
# Check to see how many differencing are needed
ndiffs(ts)
# Out:
# 1

# %%
# We need to apply differencing one time
ts_diff = ts.diff().dropna()
# Confirm stationarity with adfuller test
get_adfuller_results(ts_diff)
# Out:
#           Test Statistic  # of Lags Used  # of Observations  p-value  alpha  \
# adfuller      -15.726403               0                198      0.0   0.05
#
#           sig/stationary?
# adfuller             True

# %%
# Let's call our custom acf/pacf plot on our stationary (d = 1) data
plot_acf_pacf(ts_diff);

# %%
# First define the orders (p,d,q)
p = 1 # p is used for AR component of AR-MA model
d = 1 # 1 differcing needed to make stationary
q = 1 # q is used for MA component of AR-MA model
# Now instantiate the model with the data and fit
ar_ma_model = tsa.ARIMA(train, order = (p,d,q)).fit()
ar_ma_model
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)

# %%
# Obtain the parameters of the fit model
ar_ma_model.params
# Out:
# ar.L1    -0.629612
# ma.L1     0.144928
# sigma2    0.670682
# dtype: float64

# %% [markdown]
# #**Comparing Models**

# %%
# Obtain summary of model
ma_2_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  value   No. Observations:                  160
# Model:                 ARIMA(0, 0, 2)   Log Likelihood                -151.744
# Date:                Sun, 21 Jun 2026   AIC                            311.487
# Time:                        20:29:04   BIC                            323.788
# Sample:                    01-31-2000   HQIC                           316.482
#                          - 04-30-2013
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1051      0.125     -0.844      0.399      -0.349       0.139
# ma.L1          0.4470      0.037     12.114      0.000       0.375       0.519
# ma.L2          0.9469      0.040     23.858      0.000       0.869       1.025
# ...

# %% [markdown]
# ## Model Summary Interpretation Notes
#
# ### 1. Main Sections of `model.summary()`
#
# | Section                 | What It Means                                              | What to Look For                                                                           |
# | ----------------------- | ---------------------------------------------------------- | ------------------------------------------------------------------------------------------ |
# | **Model Specification** | Shows the model configuration used.                        | Check the order: `ARIMA(p,d,q)`                                                            |
# | **Quality of Fit**      | Shows how well the model fits the data.                    | Lower `AIC` and `BIC` are better. Higher `Log Likelihood` is better.                       |
# | **Coefficients Table**  | Shows the effect and significance of each model component. | Coefficients should ideally have `p-value < 0.05`.                                         |
# | **Diagnostic Tests**    | Tests whether residuals/errors behave well.                | Residuals should be random, independent, normally distributed, and have constant variance. |
#
# ---
#
# ### 2. Model Specification
#
# | Term             | Meaning                                                          |
# | ---------------- | ---------------------------------------------------------------- |
# | **Model**        | Shows the model type and order.                                  |
# | **ARIMA(p,d,q)** | `p` = AR order, `d` = differencing order, `q` = MA order.        |
# | **p**            | Number of autoregressive lags.                                   |
# | **d**            | Number of differencing steps used to make the series stationary. |
# | **q**            | Number of moving average error lags.                             |
#
# ---
#
# ### 3. Quality of Fit Metrics
#
# | Metric             | Meaning                                                        | Good Result       |
# | ------------------ | -------------------------------------------------------------- | ----------------- |
# | **Log Likelihood** | Measures how well the model explains the observed data.        | Higher is better. |
# | **AIC**            | Goodness-of-fit metric that balances model fit and complexity. | Lower is better.  |
# | **BIC**            | Similar to AIC, but penalizes complex models more strongly.    | Lower is better.  |
#
# **Note:**
# AIC and BIC are used to compare models. They are only fair to compare when the differencing order `d` is the same.
#
# ---
#
# ### 4. Coefficients Table
#
# | Column             | Meaning                                      | Good Result                                                   |                             |                                                        |
# | ------------------ | -------------------------------------------- | ------------------------------------------------------------- | --------------------------- | ------------------------------------------------------ |
# | **coef**           | The coefficient/value of each AR or MA term. | Shows the effect of that lag on the forecast.                 |                             |                                                        |
# | **std err**        | Standard error of the coefficient.           | Smaller is better.                                            |                             |                                                        |
# | **z**              | Z-score of the coefficient.                  | Used to test significance.                                    |                             |                                                        |
# | **P>               | z                                            | **                                                            | P-value of the coefficient. | Less than `0.05` means the coefficient is significant. |
# | **[0.025, 0.975]** | 95% confidence interval for the coefficient. | If the interval does not include 0, it supports significance. |                             |                                                        |
#
# **Note:**
# If a coefficient has `p-value > 0.05`, it may not be important. We can consider testing a simpler model without it.
#
# ---
#
# ### 5. Diagnostic Tests
#
# | Test                       | What It Checks                                           | Good Result                                  |
# | -------------------------- | -------------------------------------------------------- | -------------------------------------------- |
# | **Ljung-Box (Q)**          | Checks if residuals still have autocorrelation patterns. | `Prob(Q) > 0.05` is good.                    |
# | **Jarque-Bera (JB)**       | Checks if residuals are normally distributed.            | Higher `Prob(JB)` is better.                 |
# | **Heteroskedasticity (H)** | Checks if residual variance is constant over time.       | `H` close to 1 and `Prob(H) > 0.05` is good. |
# | **sigma²**                 | Estimated variance of the residuals/errors.              | Lower is generally better.                   |
#
# ---
#
# ### 6. Quick Decision Rules
#
# | If You See This  | Meaning                                                 |
# | ---------------- | ------------------------------------------------------- |
# | `AIC` lower      | Model may be better.                                    |
# | `BIC` lower      | Simpler and better model.                               |
# | `p-value < 0.05` | Coefficient is significant.                             |
# | `p-value > 0.05` | Coefficient may not be useful.                          |
# | `Prob(Q) > 0.05` | Residuals do not have strong remaining autocorrelation. |
# | `Prob(Q) < 0.05` | Model may have missed a pattern.                        |
# | `H` close to 1   | Residual variance is more stable.                       |
# | Low `sigma²`     | Smaller residual errors.                                |
#
# ---
#
# ### Final Note
#
# A good time series model should have:
#
# * Low AIC and BIC.
# * Significant coefficients.
# * Residuals with no remaining autocorrelation.
# * Diagnostic tests showing the residuals behave randomly.
# * Good forecast metrics such as low MAE, RMSE, and MAPE.

# %% [markdown]
# #**Diagnostic Plots**

# %%
# Obtain diagnostic plots
fig = ma_2_model.plot_diagnostics()
fig.set_size_inches(10,6)
fig.tight_layout()

# %% [markdown]
# ## Diagnostic Plots Interpretation
#
# Diagnostic plots help us check if the model residuals/errors behave correctly.
# A good model should leave residuals that look random, normally distributed, and not autocorrelated.
#
# | Plot                                 | Position     | What It Shows                                | What to Look For                                         | Warning Sign                                                                    |
# | ------------------------------------ | ------------ | -------------------------------------------- | -------------------------------------------------------- | ------------------------------------------------------------------------------- |
# | **Standardized Residuals Over Time** | Top Left     | Shows residuals/errors over time.            | Residuals should be randomly scattered around zero.      | Clear trend, pattern, or repeated structure means the model missed something.   |
# | **Histogram + Estimated Density**    | Top Right    | Shows the distribution of residuals.         | The shape should look close to a normal bell curve.      | If it is skewed or not bell-shaped, residuals may not be normally distributed.  |
# | **Normal Q-Q Plot**                  | Bottom Left  | Compares residuals to a normal distribution. | Points should follow the diagonal line.                  | Points far from the line, especially at the ends, suggest non-normal residuals. |
# | **Correlogram / ACF of Residuals**   | Bottom Right | Shows autocorrelation left in the residuals. | Most points should stay inside the blue confidence area. | Points outside the blue area mean the model missed autocorrelation patterns.    |
#
# ---
#
# ## Quick Notes
#
# * Random residuals = good sign.
# * Bell-shaped histogram = good sign.
# * Q-Q points close to the line = good sign.
# * Correlogram points inside the blue area = good sign.
# * If residuals still have patterns, the model may need different `p`, `d`, or `q` values.
#
# ---
#
# ## Final Rule
#
# A good time series model should have residuals that are:
#
# 1. Random around zero.
# 2. Close to normally distributed.
# 3. Not autocorrelated.
# 4. Mostly inside the confidence bounds in the correlogram.

# %% [markdown]
# #**Try MA(1) Model to Compare**

# %%
# First define the orders (p,d,q)
p = 0
d = 0
q = 1

# Now instantiate the model with the data and fit
ma_1_model = tsa.ARIMA(train, order = (p,d,q)).fit()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)

# %%
# Obtain model summary
ma_1_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  value   No. Observations:                  160
# Model:                 ARIMA(0, 0, 1)   Log Likelihood                -192.028
# Date:                Sun, 21 Jun 2026   AIC                            390.055
# Time:                        20:29:06   BIC                            399.281
# Sample:                    01-31-2000   HQIC                           393.801
#                          - 04-30-2013
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1047      0.076     -1.379      0.168      -0.254       0.044
# ma.L1          0.1920      0.076      2.517      0.012       0.042       0.342
# sigma2         0.6455      0.085      7.569      0.000       0.478       0.813
# ...

# %%
# Obtain diagnostic plots
fig = ma_1_model.plot_diagnostics()
fig.set_size_inches(10,6)
fig.tight_layout()

# %% [markdown]
# #**Try AR(1) MA(2) Model to Compare**

# %%
# First define the orders (p,d,q)
p = 1
d = 0
q = 2

# Now instantiate the model with the data and fit
ar_1_ma_2_model = tsa.ARIMA(train, order = (p,d,q)).fit()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)

# %%
# Obtain diagnostic plots
fig = ar_1_ma_2_model.plot_diagnostics()
fig.set_size_inches(10,6)
fig.tight_layout()

# %% [markdown]
# #**AIC**

# %%
# Looking at AIC of all three models
print(f'MA(2) had an AIC of {ma_2_model.aic.round(2)}')
print(f'MA(1) had an AIC of {ma_1_model.aic.round(2)}')
print(f'AR(1)MA(2) had an AIC of {ar_1_ma_2_model.aic.round(2)}')
# Out:
# MA(2) had an AIC of 311.49
# MA(1) had an AIC of 390.06
# AR(1)MA(2) had an AIC of 312.19

# %% [markdown]
# #**BIC**

# %%
# Looking at BIC of all three models
print(f'MA(2) had a BIC of {ma_2_model.bic.round(2)}')
print(f'MA(1) had a BIC of {ma_1_model.bic.round(2)}')
print(f'AR(1)MA(2) had a BIC of {ar_1_ma_2_model.bic.round(2)}')
# Out:
# MA(2) had a BIC of 323.79
# MA(1) had a BIC of 399.28
# AR(1)MA(2) had a BIC of 327.57
