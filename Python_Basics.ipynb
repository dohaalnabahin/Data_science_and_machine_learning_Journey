# %% [markdown]
# <a href="https://colab.research.google.com/github/dohaalnabahin/Python-Learning-Journey/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **جملة طباعة **

# %%
print("Hello Doha! Welcome to Python world.")
# Out:
# Hello Doha! Welcome to Python world.

# %% [markdown]
# تات

# %%
print("Hello Doha! Welcome to Python world.")
# Out:
# Hello Doha! Welcome to Python world.

# %% [markdown]
# # var
# الدرس الاول المتغيرانت

# %%
print("Hello Doha! Welcome to Python world.")
# Out:
# Hello Doha! Welcome to Python world.
