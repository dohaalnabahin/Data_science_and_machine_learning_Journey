# %% [markdown]
# <a href="https://colab.research.google.com/github/dohaalnabahin/Data_science_and_machine_learning_Journey/blob/main/Univariate_Categorical_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',100)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fpath="/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week03/Data/ames-housing-cleaned-eda.csv"
df = pd.read_csv(fpath)
df.head()
# Out:
#          PID MS Zoning  Lot Frontage  Lot Area Street    Alley Utilities  \
# 0  907227090        RL            60      7200   Pave  MISSING    AllPub
# 1  527108010        RL           134     19378   Pave  MISSING    AllPub
# 2  534275170        RL            -1     12772   Pave  MISSING    AllPub
# 3  528104050        RL           114     14803   Pave  MISSING    AllPub
# 4  533206070        FV            32      3784   Pave     Pave    AllPub
#
#   Neighborhood Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0      CollgCr      1Fam      1Story             5             8        1972
# 1      Gilbert      1Fam      2Story             7             5        2005
# 2        NAmes      1Fam      1Story             6             8        1960
# 3      NridgHt      1Fam      1Story            10             5        2007
# 4      Somerst    TwnhsE      1Story             8             5        2006
#
#    Year Remodeled Exter Qual Exter Cond  Bsmt Unf Sqft  Total Bsmnt Sqft  \
# 0            1972         TA         TA          427.0             864.0
# 1            2006         Gd         TA         1335.0            1392.0
# 2            1998         TA         Gd          460.0             958.0
# 3            2008         Ex         TA          442.0            2078.0
# 4            2007         Gd         TA         1451.0            1511.0
#
#   Central Air  Living Area Sqft  Bedroom  Kitchen  Total Rooms Garage Type  \
# 0           Y             864.0        3        1            5      Detchd
# 1           Y            2462.0        4        1            9      Attchd
# 2           Y             958.0        2        1            5      Attchd
# 3           Y            2084.0        2        1            7      Attchd
# 4           Y            1565.0        2        1            5      Attchd
#
#    Garage Yr Blt  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 0         1977.0          1.0        297.0          TA          TA
# 1         2006.0          2.0        576.0          TA          TA
# 2         1960.0          1.0        301.0          TA          TA
# 3         2007.0          3.0       1220.0          TA          TA
# 4         2006.0          2.0        476.0          TA          TA
#
#   Paved Drive    Fence  SalePrice  Month  Year  Total Full Baths  \
# 0           Y    MnPrv   119900.0      3  2006               1.0
# 1           Y  MISSING   320000.0      3  2006               3.0
# 2           Y  MISSING   151500.0      4  2007               1.0
# 3           Y  MISSING   385000.0      6  2008               3.0
# 4           Y  MISSING   193800.0      2  2007               3.0
#
#    Total Half Baths
# 0               0.0
# 1               1.0
# 2               0.0
# 3               0.0
# 4               0.0

# %%
# Using select dtypes to get names of categorical columns
cat_cols = df.select_dtypes('object').columns
cat_cols
# Out:
# Index(['MS Zoning', 'Street', 'Alley', 'Utilities', 'Neighborhood',
#        'Bldg Type', 'House Style', 'Exter Qual', 'Exter Cond', 'Central Air',
#        'Garage Type', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Fence'],
#       dtype='object')

# %%
# Checking how many categories in each column
df[cat_cols].nunique()
# Out:
# MS Zoning        7
# Street           2
# Alley            3
# Utilities        3
# Neighborhood    28
# Bldg Type        5
# House Style      8
# Exter Qual       4
# Exter Cond       5
# Central Air      2
# Garage Type      7
# Garage Qual      6
# Garage Cond      6
# Paved Drive      3
# Fence            5
# dtype: int64

# %% [markdown]
# #**Categorical Plots with Pandas**

# %%
# Saving the value counts
val_counts = df['Alley'].value_counts()
val_counts
# Out:
# Alley
# MISSING    2732
# Grvl        120
# Pave         78
# Name: count, dtype: int64

# %%
# Plot value counts as a bar graph
ax = val_counts.plot(kind='bar')
ax.set_ylabel("Count(# of Homes)");
ax.set_xlabel("Alley");

# %% [markdown]
# #**Plotting the Frequency (Value Counts as a % of total)**

# %%
# Saving the Normalized Value Counts
val_counts_norm = df['Alley'].value_counts(normalize=True) * 100
val_counts_norm
# Out:
# Alley
# MISSING    93.242321
# Grvl        4.095563
# Pave        2.662116
# Name: proportion, dtype: float64

# %%
# Plot value counts as a bar graph
ax = val_counts_norm.plot(kind='bar')
ax.set_ylabel("Frequency (% of Homes)");
ax.set_xlabel("Alley");

# %% [markdown]
# #**Categorical Plots with Seaborn**

# %%
# Seaborn countplot
ax = sns.countplot(data=df, x="Alley")

# %% [markdown]
# #**Visualizing Many Categories**

# %%
# Checking the nunique in cat_cols
df[cat_cols].nunique()
# Out:
# MS Zoning        7
# Street           2
# Alley            3
# Utilities        3
# Neighborhood    28
# Bldg Type        5
# House Style      8
# Exter Qual       4
# Exter Cond       5
# Central Air      2
# Garage Type      7
# Garage Qual      6
# Garage Cond      6
# Paved Drive      3
# Fence            5
# dtype: int64

# %%
# Countplot with many categories
ax = sns.countplot(data=df, x="Neighborhood")

# %%
# Countplot with many categories, rotate labels
ax = sns.countplot(data=df, x="Neighborhood");
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right');
# Out:
# /tmp/ipykernel_160/4125848806.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right');

# %% [markdown]
# #**Ordering Groups in Seaborn Plots**

# %%
# Saving the value_counts to use with seaborn
val_counts = df['Neighborhood'].value_counts()
val_counts.head(10)
# Out:
# Neighborhood
# NAmes      443
# CollgCr    267
# OldTown    239
# Edwards    194
# Somerst    182
# NridgHt    166
# Gilbert    165
# Sawyer     151
# NWAmes     131
# SawyerW    125
# Name: count, dtype: int64

# %%
# We need to use the val_counts.index to get the names in order
val_counts.index
# Out:
# Index(['NAmes', 'CollgCr', 'OldTown', 'Edwards', 'Somerst', 'NridgHt',
#        'Gilbert', 'Sawyer', 'NWAmes', 'SawyerW', 'Mitchel', 'BrkSide',
#        'Crawfor', 'IDOTRR', 'Timber', 'NoRidge', 'StoneBr', 'SWISU', 'ClearCr',
#        'MeadowV', 'BrDale', 'Blmngtn', 'Veenker', 'NPkVill', 'Blueste',
#        'Greens', 'GrnHill', 'Landmrk'],
#       dtype='object', name='Neighborhood')

# %%
# Creating a Countplot with seaborn (ordered by count)
ax = sns.countplot(data=df, x="Neighborhood",
                   order=val_counts.index)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right');
# Out:
# /tmp/ipykernel_160/621385940.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right');
