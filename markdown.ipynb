# %% [markdown]
# <a href="https://colab.research.google.com/github/dohaalnabahin/Data_science_and_machine_learning_Journey/blob/main/markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Headers**
# # header 1
# ## header 2
# ### header 3
# #### header 4
#
# **Lists**
# **Bulleted Lists (Un-Ordered Lists)**
#
# - This is the first (outer) bullet
#
# **Nested Bullet Gotcha's**
#
#  - This is the first (outer) bullet
#    - This bullet is too tabbed over and will not be rendered correctly.
#    - Every following bullet will also be not rendered correctly.
#
#  **Numbered Lists**
#   1. number 1
#   2. number 2
#   3. number 3
#
#   **Check Boxes**
#
#  -  To-Dos:
#     - [x] Add checkboxes!
#     - [ ] Solve world hunger.
#
# **Text Formatting**
# **Bold Text**
#
# n this sentence, only **these three words** will be bolded
#
# **Italics**
#
# *Italics*
#
# **Bold + Italics**
#
# In this sentence, only ***these three words*** will be bolded and italicized
#
# **Strikethrough**
# The best online coding boot camp is ~~someone else~~ AXSOS ACADEMY!
#
# **Inserting Images & Links**
# **Links**
# [This text will be displayed as the link](https://colab.research.google.com/)
#
# **image**
# ![](https://Axsos.de/photos/academy/2024/1)
#
# **Quote Blocks**
# > This sentence will be a quotation.
#
# **Horizontal Lines**
#
# Text above the line.
#
# ---
#
# Text below the line.
