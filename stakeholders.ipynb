# %% [markdown]
# <a href="https://colab.research.google.com/github/dohaalnabahin/Data_science_and_machine_learning_Journey/blob/main/stakeholders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
fpath = "/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/ames-housing-dojo.csv"
df = pd.read_csv(fpath)
df.head()
# Out:
#    Unnamed: 0        PID MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0           0  907227090        RL            60      7200   Pave   NaN
# 1           1  527108010        RL           134     19378   Pave   NaN
# 2           2  534275170        RL            -1     12772   Pave   NaN
# 3           3  528104050        RL           114     14803   Pave   NaN
# 4           4  533206070        FV            32      3784   Pave  Pave
#
#   Utilities Neighborhood Bldg Type  ... Garage Type  Garage Yr Blt  \
# 0    AllPub      CollgCr      1Fam  ...      Detchd         1977.0
# 1    AllPub      Gilbert      1Fam  ...      Attchd         2006.0
# 2    AllPub        NAmes      1Fam  ...      Attchd         1960.0
# 3    AllPub      NridgHt      1Fam  ...      Attchd         2007.0
# 4    AllPub      Somerst    TwnhsE  ...      Attchd         2006.0
#
#    Garage Cars  Garage Area  Garage Qual Garage Cond Paved Drive  Fence  \
# ...

# %%
# Demo: Finding the Current Max Cols
pd.get_option('display.max_columns')
# Out:
# 20

# %%
# Setting the max_columns to 50
pd.set_option('display.max_columns',50)

# %%
# Run df.head() again to see full dataset
df.head()
# Out:
#    Unnamed: 0        PID MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0           0  907227090        RL            60      7200   Pave   NaN
# 1           1  527108010        RL           134     19378   Pave   NaN
# 2           2  534275170        RL            -1     12772   Pave   NaN
# 3           3  528104050        RL           114     14803   Pave   NaN
# 4           4  533206070        FV            32      3784   Pave  Pave
#
#   Utilities Neighborhood Bldg Type House Style  Overall Qual  Overall Cond  \
# 0    AllPub      CollgCr      1Fam      1Story             5             8
# 1    AllPub      Gilbert      1Fam      2Story             7             5
# 2    AllPub        NAmes      1Fam      1Story             6             8
# 3    AllPub      NridgHt      1Fam      1Story            10             5
# 4    AllPub      Somerst    TwnhsE      1Story             8             5
#
#    Year Built  Year Remod/Add Exter Qual Exter Cond  Bsmt Unf SF  \
# ...

# %%
# Preview the last 10 rows
df.tail(10)
# Out:
#       Unnamed: 0        PID MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 2949        2949  528228280        RL            43      3087   Pave   NaN
# 2950        2950  528112010        RL           108     12228   Pave   NaN
# 2951        2951  535377090        RL            64      6979   Pave   NaN
# 2952        2952  908102040        RL            67      8777   Pave   NaN
# 2953        2953  535150300        RL           174     25419   Pave   NaN
# 2954        2954  903400030        RL            50     11672   Pave  Pave
# 2955        2955  533234020        FV            79     10646   Pave   NaN
# 2956        2956  908188140        RM            24      2522   Pave   NaN
# 2957        2957  909254050        RL            54      7609   Pave   NaN
# 2958        2958  902201120        RM            50      6000   Pave   NaN
#
#      Utilities Neighborhood Bldg Type House Style  Overall Qual  Overall Cond  \
# ...

# %%
# How many rows?
len(df)
# Out:
# 2959

# %%
 #How many columns?
len(df.columns)
# Out:
# 38

# %%
# Can get both once from shape (row, col)
df.shape
# Out:
# (2959, 38)

# %%
# Find datatypes of each column
df.dtypes
# Out:
# Unnamed: 0          int64
# PID                 int64
# MS Zoning          object
# Lot Frontage        int64
# Lot Area            int64
# Street             object
# Alley              object
# Utilities          object
# Neighborhood       object
# Bldg Type          object
# House Style        object
# Overall Qual        int64
# Overall Cond        int64
# Year Built          int64
# Year Remod/Add      int64
# Exter Qual         object
# Exter Cond         object
# Bsmt Unf SF       float64
# Total Bsmt SF     float64
# Central Air        object
# Gr Liv Area        object
# Bsmt Full Bath    float64
# Bsmt Half Bath    float64
# Full Bath           int64
# Half Bath          object
# Bedroom             int64
# Kitchen             int64
# TotRms AbvGrd       int64
# Garage Type        object
# Garage Yr Blt     float64
# Garage Cars       float64
# Garage Area       float64
# Garage Qual        object
# Garage Cond        object
# Paved Drive        object
# ...

# %%
# Check the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2959 entries, 0 to 2958
# Data columns (total 38 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      2959 non-null   int64
#  1   PID             2959 non-null   int64
#  2   MS Zoning       2959 non-null   object
#  3   Lot Frontage    2959 non-null   int64
#  4   Lot Area        2959 non-null   int64
#  5   Street          2959 non-null   object
#  6   Alley           201 non-null    object
#  7   Utilities       2959 non-null   object
#  8   Neighborhood    2959 non-null   object
#  9   Bldg Type       2959 non-null   object
#  10  House Style     2959 non-null   object
#  11  Overall Qual    2959 non-null   int64
#  12  Overall Cond    2959 non-null   int64
#  13  Year Built      2959 non-null   int64
#  14  Year Remod/Add  2959 non-null   int64
#  15  Exter Qual      2959 non-null   object
#  16  Exter Cond      2959 non-null   object
# ...

# %%
# Check the datatype for a particular column
df['Gr Liv Area'].dtypes
# Out:
# dtype('O')

# %%
# Check the value_counts for Living Area Sqft
df['Gr Liv Area'].value_counts()
# Out:
# Gr Liv Area
# 864sqft     41
# 1092sqft    27
# 1040sqft    25
# 1456sqft    20
# 1200sqft    18
#             ..
# 1863sqft     1
# 2582sqft     1
# 1357sqft     1
# 3500sqft     1
# 2076sqft     1
# Name: count, Length: 1292, dtype: int64

# %%
# Replace Sqft with nothing
df['Gr Liv Area'] = df['Gr Liv Area'].str.replace("sqft",'')
df['Gr Liv Area'].head()
# Out:
# 0     864
# 1    2462
# 2     958
# 3    2084
# 4    1565
# Name: Gr Liv Area, dtype: object

# %%
# Convert the column to a float
df['Gr Liv Area'] = df['Gr Liv Area'].astype(float)
df['Gr Liv Area'].dtype
# Out:
# dtype('float64')

# %%
# Dropping unnamed 0 (permanently)
df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#          PID MS Zoning  Lot Frontage  Lot Area Street Alley Utilities  \
# 0  907227090        RL            60      7200   Pave   NaN    AllPub
# 1  527108010        RL           134     19378   Pave   NaN    AllPub
# 2  534275170        RL            -1     12772   Pave   NaN    AllPub
# 3  528104050        RL           114     14803   Pave   NaN    AllPub
# 4  533206070        FV            32      3784   Pave  Pave    AllPub
#
#   Neighborhood Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0      CollgCr      1Fam      1Story             5             8        1972
# 1      Gilbert      1Fam      2Story             7             5        2005
# 2        NAmes      1Fam      1Story             6             8        1960
# 3      NridgHt      1Fam      1Story            10             5        2007
# 4      Somerst    TwnhsE      1Story             8             5        2006
#
#    Year Remod/Add Exter Qual Exter Cond  Bsmt Unf SF  Total Bsmt SF  \
# ...

# %%
# Create a dictionary using old column name : new column name format
rename_dict = {"Year Remod/Add":"Year Remodeled",
               "Bsmt Unf SF": "Bsmt Unf Sqft",
               "Total Bsmt SF": "Total Bsmnt Sqft",
               "TotRms AbvGrd": "Total Rooms",
               "Gr Liv Area":"Living Area Sqft"}
rename_dict
# Out:
# {'Year Remod/Add': 'Year Remodeled',
#  'Bsmt Unf SF': 'Bsmt Unf Sqft',
#  'Total Bsmt SF': 'Total Bsmnt Sqft',
#  'TotRms AbvGrd': 'Total Rooms',
#  'Gr Liv Area': 'Living Area Sqft'}

# %%
# dictionary substitution using rename method
df = df.rename(rename_dict,axis=1)
df.head()
# Out:
#          PID MS Zoning  Lot Frontage  Lot Area Street Alley Utilities  \
# 0  907227090        RL            60      7200   Pave   NaN    AllPub
# 1  527108010        RL           134     19378   Pave   NaN    AllPub
# 2  534275170        RL            -1     12772   Pave   NaN    AllPub
# 3  528104050        RL           114     14803   Pave   NaN    AllPub
# 4  533206070        FV            32      3784   Pave  Pave    AllPub
#
#   Neighborhood Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0      CollgCr      1Fam      1Story             5             8        1972
# 1      Gilbert      1Fam      2Story             7             5        2005
# 2        NAmes      1Fam      1Story             6             8        1960
# 3      NridgHt      1Fam      1Story            10             5        2007
# 4      Somerst    TwnhsE      1Story             8             5        2006
#
#    Year Remodeled Exter Qual Exter Cond  Bsmt Unf Sqft  Total Bsmnt Sqft  \
# ...

# %%
# save the filter
duplicated_rows = df.duplicated()
duplicated_rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2954    False
# 2955    False
# 2956    False
# 2957    False
# 2958    False
# Length: 2959, dtype: bool

# %%
# Count the duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Visually checking the duplicate rows
df[duplicated_rows]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, PID, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Utilities, Neighborhood, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Exter Qual, Exter Cond, Bsmt Unf SF, Total Bsmt SF, Central Air, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom, Kitchen, TotRms AbvGrd, Garage Type, Garage Yr Blt, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Fence, Date Sold, SalePrice]
# Index: []
#
# [0 rows x 38 columns]

# %%
# Include the first row along with all dupicates
duplicated_rows = df.duplicated(keep=False)
duplicated_rows.sum()
# Out:
# np.int64(0)

# %%
# Display duplicates
df[duplicated_rows].sort_values("PID")
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, PID, MS Zoning, Lot Frontage, Lot Area, Street, Alley, Utilities, Neighborhood, Bldg Type, House Style, Overall Qual, Overall Cond, Year Built, Year Remod/Add, Exter Qual, Exter Cond, Bsmt Unf SF, Total Bsmt SF, Central Air, Gr Liv Area, Bsmt Full Bath, Bsmt Half Bath, Full Bath, Half Bath, Bedroom, Kitchen, TotRms AbvGrd, Garage Type, Garage Yr Blt, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Fence, Date Sold, SalePrice]
# Index: []
#
# [0 rows x 38 columns]

# %%
# Remove duplicates
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check for how many unique values are in each column
df.nunique()
# Out:
# Unnamed: 0        2959
# PID               2930
# MS Zoning            7
# Lot Frontage       129
# Lot Area          1960
# Street               2
# Alley                2
# Utilities            3
# Neighborhood        28
# Bldg Type            5
# House Style          8
# Overall Qual        10
# Overall Cond         9
# Year Built         118
# Year Remod/Add      61
# Exter Qual           4
# Exter Cond           5
# Bsmt Unf SF       1137
# Total Bsmt SF     1058
# Central Air          4
# Gr Liv Area       1292
# Bsmt Full Bath       4
# Bsmt Half Bath       3
# Full Bath            5
# Half Bath            4
# Bedroom              8
# Kitchen              4
# TotRms AbvGrd       14
# Garage Type          6
# Garage Yr Blt      103
# Garage Cars          6
# Garage Area        603
# Garage Qual          5
# Garage Cond          5
# Paved Drive          3
# Fence                4
# Date Sold           55
# SalePrice         1033
# dtype: int64

# %%
# شوفي كم بيت "فريد" عندك في الجدول
df['PID'].nunique()
# Out:
# 2930

# %%
# هاد الكود رح يورجيكي الـ 29 بيت اللي فيهم مشكلة
df[df.duplicated(subset=['PID'], keep=False)].sort_values('PID')
# Out:
#       Unnamed: 0        PID MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 290          290  526351010        RL            81     14267   Pave   NaN
# 2029        2029  526351010        RL            81     14267   Pave   NaN
# 1650        1650  526355080        RL            75     13860   Pave   NaN
# 2654        2654  526355080        RL            75     13860   Pave   NaN
# 2469        2469  527110020        RL            -1      8530   Pave   NaN
# 135          135  527110020        RL            -1      8530   Pave   NaN
# 626          626  527326040        RL            85     11900   Pave   NaN
# 625          625  527326040        RL            85     11900   Pave   NaN
# 1100        1100  528174020        RL            34      3901   Pave   NaN
# 2552        2552  528174020        RL            34      3901   Pave   NaN
# 2341        2341  528178070        RL           130     16900   Pave   NaN
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0        2930
# PID               2930
# MS Zoning            7
# Lot Frontage       129
# Lot Area          1960
# Street               2
# Alley                2
# Utilities            3
# Neighborhood        28
# Bldg Type            5
# House Style          8
# Overall Qual        10
# Overall Cond         9
# Year Built         118
# Year Remod/Add      61
# Exter Qual           4
# Exter Cond           5
# Bsmt Unf SF       1137
# Total Bsmt SF     1058
# Central Air          4
# Gr Liv Area       1292
# Bsmt Full Bath       4
# Bsmt Half Bath       3
# Full Bath            5
# Half Bath            4
# Bedroom              8
# Kitchen              4
# TotRms AbvGrd       14
# Garage Type          6
# Garage Yr Blt      103
# Garage Cars          6
# Garage Area        603
# Garage Qual          5
# Garage Cond          5
# Paved Drive          3
# Fence                4
# Date Sold           55
# SalePrice         1031
# dtype: int64

# %%
# What is the percentage of unique values in each column
df.nunique() / len(df) * 100
# Out:
# Unnamed: 0        100.000000
# PID               100.000000
# MS Zoning           0.238908
# Lot Frontage        4.402730
# Lot Area           66.894198
# Street              0.068259
# Alley               0.068259
# Utilities           0.102389
# Neighborhood        0.955631
# Bldg Type           0.170648
# House Style         0.273038
# Overall Qual        0.341297
# Overall Cond        0.307167
# Year Built          4.027304
# Year Remod/Add      2.081911
# Exter Qual          0.136519
# Exter Cond          0.170648
# Bsmt Unf SF        38.805461
# Total Bsmt SF      36.109215
# Central Air         0.136519
# Gr Liv Area        44.095563
# Bsmt Full Bath      0.136519
# Bsmt Half Bath      0.102389
# Full Bath           0.170648
# Half Bath           0.136519
# Bedroom             0.273038
# Kitchen             0.136519
# TotRms AbvGrd       0.477816
# Garage Type         0.204778
# Garage Yr Blt       3.515358
# Garage Cars         0.204778
# Garage Area        20.580205
# ...

# %%
# Visually checking the duplicate rows
df[duplicated_pids].sort_values("PID")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2408108868.py in <cell line: 0>()
#       1 # Visually checking the duplicate rows
# ----> 2 df[duplicated_pids].sort_values("PID")
#
# NameError: name 'duplicated_pids' is not defined

# %%
# Identify if a value is null or not
df.isna()
# Out:
#       Unnamed: 0    PID  MS Zoning  Lot Frontage  Lot Area  Street  Alley  \
# 0          False  False      False         False     False   False   True
# 1          False  False      False         False     False   False   True
# 2          False  False      False         False     False   False   True
# 3          False  False      False         False     False   False   True
# 4          False  False      False         False     False   False  False
# ...          ...    ...        ...           ...       ...     ...    ...
# 2954       False  False      False         False     False   False  False
# 2955       False  False      False         False     False   False   True
# 2956       False  False      False         False     False   False   True
# 2957       False  False      False         False     False   False   True
# 2958       False  False      False         False     False   False   True
#
#       Utilities  Neighborhood  Bldg Type  ...  Garage Type  Garage Yr Blt  \
# ...

# %%
# This will give us the total number of null values (True) for each column
null_sums = df.isna().sum()
null_sums
# Out:
# Unnamed: 0           0
# PID                  0
# MS Zoning            0
# Lot Frontage         0
# Lot Area             0
# Street               0
# Alley             2758
# Utilities            0
# Neighborhood         0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Exter Qual           0
# Exter Cond           0
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Central Air          0
# Gr Liv Area          0
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Full Bath            0
# Half Bath            0
# Bedroom              0
# Kitchen              0
# TotRms AbvGrd        0
# Garage Type        157
# Garage Yr Blt      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Paved Drive          0
# Fence             2385
# Date Sold            0
# SalePrice           22
# dtype: int64

# %%
# Check the datatype
type(null_sums)
# Out:
# pandas.core.series.Series

# %%
# Get the % of null values
null_percent = null_sums/len(df) * 100
null_percent
# Out:
# Unnamed: 0         0.000000
# PID                0.000000
# MS Zoning          0.000000
# Lot Frontage       0.000000
# Lot Area           0.000000
# Street             0.000000
# Alley             93.207165
# Utilities          0.000000
# Neighborhood       0.000000
# Bldg Type          0.000000
# House Style        0.000000
# Overall Qual       0.000000
# Overall Cond       0.000000
# Year Built         0.000000
# Year Remod/Add     0.000000
# Exter Qual         0.000000
# Exter Cond         0.000000
# Bsmt Unf SF        0.033795
# Total Bsmt SF      0.033795
# Central Air        0.000000
# Gr Liv Area        0.000000
# Bsmt Full Bath     0.067590
# Bsmt Half Bath     0.067590
# Full Bath          0.000000
# Half Bath          0.000000
# Bedroom            0.000000
# Kitchen            0.000000
# TotRms AbvGrd      0.000000
# Garage Type        5.305847
# Garage Yr Blt      5.373437
# Garage Cars        0.033795
# Garage Area        0.033795
# Garage Qual        5.373437
# ...

# %%
# Viewing only columns with null values
null_percent[null_percent>0]
# Out:
# Alley             93.207165
# Bsmt Unf SF        0.033795
# Total Bsmt SF      0.033795
# Bsmt Full Bath     0.067590
# Bsmt Half Bath     0.067590
# Garage Type        5.305847
# Garage Yr Blt      5.373437
# Garage Cars        0.033795
# Garage Area        0.033795
# Garage Qual        5.373437
# Garage Cond        5.373437
# Fence             80.601555
# SalePrice          0.743494
# dtype: float64

# %%
import missingno as msno
msno.matrix(df);

# %%
# save the filter
null_garage_type = df['Garage Type'].isna()
null_garage_type
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2954    False
# 2955    False
# 2956    False
# 2957    False
# 2958    False
# Name: Garage Type, Length: 2959, dtype: bool

# %%
# Use the filter
df[null_garage_type]
# Out:
#       Unnamed: 0        PID MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 20            20  903458110        RM            -1      7920   Pave  Grvl
# 21            21  908225310        RL            52      8741   Pave   NaN
# 28            28  904301060        RL            60     10800   Pave   NaN
# 79            79  527401160        RL            60      9000   Pave   NaN
# 85            85  904351040   C (all)            -1      6449   Pave   NaN
# ...          ...        ...       ...           ...       ...    ...   ...
# 2917        2917  903225050        RM            50      6130   Pave   NaN
# 2919        2919  923275140        RL            -1      8780   Pave   NaN
# 2936        2936  904301375        RL            -1     10020   Pave   NaN
# 2941        2941  534276360        RL            77      9320   Pave   NaN
# 2952        2952  908102040        RL            67      8777   Pave   NaN
#
# ...

# %%
duplicated_pids = df.duplicated(subset=['PID'], keep=False)

# %%
# Revisiting the duplicate rows with null values from duplicates lesson
df[duplicated_pids].sort_values("PID")
# Out:
#       Unnamed: 0        PID MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 290          290  526351010        RL            81     14267   Pave   NaN
# 2029        2029  526351010        RL            81     14267   Pave   NaN
# 1650        1650  526355080        RL            75     13860   Pave   NaN
# 2654        2654  526355080        RL            75     13860   Pave   NaN
# 2469        2469  527110020        RL            -1      8530   Pave   NaN
# 135          135  527110020        RL            -1      8530   Pave   NaN
# 626          626  527326040        RL            85     11900   Pave   NaN
# 625          625  527326040        RL            85     11900   Pave   NaN
# 1100        1100  528174020        RL            34      3901   Pave   NaN
# 2552        2552  528174020        RL            34      3901   Pave   NaN
# 2341        2341  528178070        RL           130     16900   Pave   NaN
# ...

# %%
# Dropping Null values from SalePrice
df = df.dropna(subset=["SalePrice"])

# %%
# Confirming no more null sale prices
df['SalePrice'].isna().sum()
# Out:
# np.int64(0)

# %%
# Confirming  no more duplicated PIDs
df.duplicated(subset=['PID'], keep=False).sum()
# Out:
# np.int64(0)

# %%
# حذف الصفوف المكررة بناءً على رقم الـ PID وإبقاء النسخة الأولى فقط
df = df.drop_duplicates(subset=['PID'])

# الآن تأكد مرة أخرى
df.duplicated(subset=['PID']).sum()
# Out:
# np.int64(0)

# %%
# Confirming PID is 100% unique now
df['PID'].nunique()/len(df) *100
# Out:
# 100.0

# %%
# Set the index to PID
df = df.set_index("PID")
df.head()
# Out:
#            Unnamed: 0 MS Zoning  Lot Frontage  Lot Area Street Alley  \
# PID
# 907227090           0        RL            60      7200   Pave   NaN
# 527108010           1        RL           134     19378   Pave   NaN
# 534275170           2        RL            -1     12772   Pave   NaN
# 528104050           3        RL           114     14803   Pave   NaN
# 533206070           4        FV            32      3784   Pave  Pave
#
#           Utilities Neighborhood Bldg Type House Style  ...  Garage Type  \
# PID                                                     ...
# 907227090    AllPub      CollgCr      1Fam      1Story  ...       Detchd
# 527108010    AllPub      Gilbert      1Fam      2Story  ...       Attchd
# 534275170    AllPub        NAmes      1Fam      1Story  ...       Attchd
# 528104050    AllPub      NridgHt      1Fam      1Story  ...       Attchd
# 533206070    AllPub      Somerst    TwnhsE      1Story  ...       Attchd
#
# ...

# %%
# Inspect the datatype for each column
df.dtypes
# Out:
# Unnamed: 0          int64
# MS Zoning          object
# Lot Frontage        int64
# Lot Area            int64
# Street             object
# Alley              object
# Utilities          object
# Neighborhood       object
# Bldg Type          object
# House Style        object
# Overall Qual        int64
# Overall Cond        int64
# Year Built          int64
# Year Remod/Add      int64
# Exter Qual         object
# Exter Cond         object
# Bsmt Unf SF       float64
# Total Bsmt SF     float64
# Central Air        object
# Gr Liv Area        object
# Bsmt Full Bath    float64
# Bsmt Half Bath    float64
# Full Bath           int64
# Half Bath          object
# Bedroom             int64
# Kitchen             int64
# TotRms AbvGrd       int64
# Garage Type        object
# Garage Yr Blt     float64
# Garage Cars       float64
# Garage Area       float64
# Garage Qual        object
# Garage Cond        object
# Paved Drive        object
# Fence              object
# ...

# %%
# Saving list of column names for object cols
cat_cols = df.select_dtypes('object').columns
cat_cols
# Out:
# Index(['MS Zoning', 'Street', 'Alley', 'Utilities', 'Neighborhood',
#        'Bldg Type', 'House Style', 'Exter Qual', 'Exter Cond', 'Central Air',
#        'Gr Liv Area', 'Half Bath', 'Garage Type', 'Garage Qual', 'Garage Cond',
#        'Paved Drive', 'Fence', 'Date Sold'],
#       dtype='object')

# %%
# Saving list of column names for numeric cols
num_cols = df.select_dtypes('number').columns
num_cols
# Out:
# Index(['Unnamed: 0', 'Lot Frontage', 'Lot Area', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Bsmt Unf SF',
#        'Total Bsmt SF', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Bedroom', 'Kitchen', 'TotRms AbvGrd', 'Garage Yr Blt', 'Garage Cars',
#        'Garage Area', 'SalePrice'],
#       dtype='object')

# %%
# Checking which categorical columns had missing values.
df[cat_cols].isna().sum()
# Out:
# MS Zoning          0
# Street             0
# Alley           2732
# Utilities          0
# Neighborhood       0
# Bldg Type          0
# House Style        0
# Exter Qual         0
# Exter Cond         0
# Central Air        0
# Gr Liv Area        0
# Half Bath          0
# Garage Type      157
# Garage Qual      159
# Garage Cond      159
# Paved Drive        0
# Fence           2358
# Date Sold          0
# dtype: int64

# %%
# Using fillna to fill Alley's nulls with "MISSING"
df['Alley'] = df['Alley'].fillna("MISSING")
df['Alley'].value_counts(dropna=False)

# %%
 #MUsing fillna to fill Alley's nulls with "MISSING"
df['Alley'] = df['Alley'].fillna("MISSING")
df['Alley'].value_counts(dropna=False)
# Out:
# Alley
# MISSING    2732
# Grvl        120
# Pave         78
# Name: count, dtype: int64

# %%
# Using the list of cat_cols to fillna
df[cat_cols] = df[cat_cols].fillna("MISSING")

# %%
# Confirm that all null values have been filled for categorical columns
df[cat_cols].isna().sum()
# Out:
# MS Zoning       0
# Street          0
# Alley           0
# Utilities       0
# Neighborhood    0
# Bldg Type       0
# House Style     0
# Exter Qual      0
# Exter Cond      0
# Central Air     0
# Gr Liv Area     0
# Half Bath       0
# Garage Type     0
# Garage Qual     0
# Garage Cond     0
# Paved Drive     0
# Fence           0
# Date Sold       0
# dtype: int64

# %%
# Check numeric features for null values
df[num_cols].isna().sum()
# Out:
# Unnamed: 0          0
# Lot Frontage        0
# Lot Area            0
# Overall Qual        0
# Overall Cond        0
# Year Built          0
# Year Remod/Add      0
# Bsmt Unf SF         1
# Total Bsmt SF       1
# Bsmt Full Bath      2
# Bsmt Half Bath      2
# Full Bath           0
# Bedroom             0
# Kitchen             0
# TotRms AbvGrd       0
# Garage Yr Blt     159
# Garage Cars         1
# Garage Area         1
# SalePrice           0
# dtype: int64

# %%
# Create a filter for null values in Garage Yr Blt
null_garage = df['Garage Yr Blt'].isna()
# Use the filter to display only the rows with null values in Garage Yr Blt
df[null_garage]
# Out:
#            Unnamed: 0 MS Zoning  Lot Frontage  Lot Area Street    Alley  \
# PID
# 903458110          20        RM            -1      7920   Pave     Grvl
# 908225310          21        RL            52      8741   Pave  MISSING
# 904301060          28        RL            60     10800   Pave  MISSING
# 527401160          79        RL            60      9000   Pave  MISSING
# 904351040          85   C (all)            -1      6449   Pave  MISSING
# ...               ...       ...           ...       ...    ...      ...
# 903225050        2917        RM            50      6130   Pave  MISSING
# 923275140        2919        RL            -1      8780   Pave  MISSING
# 904301375        2936        RL            -1     10020   Pave  MISSING
# 534276360        2941        RL            77      9320   Pave  MISSING
# 908102040        2952        RL            67      8777   Pave  MISSING
#
#           Utilities Neighborhood Bldg Type House Style  ...  Garage Type  \
# ...

# %%
# Obtain summary statistics for the Garage Yr Blt
df['Garage Yr Blt'].describe()
# Out:
# count    2771.000000
# mean     1978.132443
# std        25.528411
# min      1895.000000
# 25%      1960.000000
# 50%      1979.000000
# 75%      2002.000000
# max      2207.000000
# Name: Garage Yr Blt, dtype: float64

# %%
# checking the rows with 2207 for Garage Yr Built
df[df['Garage Yr Blt'] == 2207]
# Out:
#            Unnamed: 0 MS Zoning  Lot Frontage  Lot Area Street    Alley  \
# PID
# 916384070        1589        RL            68      8298   Pave  MISSING
#
#           Utilities Neighborhood Bldg Type House Style  ...  Garage Type  \
# PID                                                     ...
# 916384070    AllPub       Timber      1Fam      1Story  ...       Attchd
#
#            Garage Yr Blt  Garage Cars  Garage Area Garage Qual Garage Cond  \
# PID
# 916384070         2207.0          2.0        502.0          TA          TA
#
#            Paved Drive    Fence Date Sold SalePrice
# PID
# 916384070            Y  MISSING   09-2007  267300.0
#
# [1 rows x 37 columns]

# %%
# Create a filter to identify the row with the typo
filter_typo_garage_year = df['Garage Yr Blt'] == 2207
filter_typo_garage_year
# Out:
# PID
# 907227090    False
# 527108010    False
# 534275170    False
# 528104050    False
# 533206070    False
#              ...
# 903400030    False
# 533234020    False
# 908188140    False
# 909254050    False
# 902201120    False
# Name: Garage Yr Blt, Length: 2930, dtype: bool

# %%
# أنتِ الآن قررتِ أن سنة 2207 هي قيمة مستحيلة وستخرب عليكِ الحسابات، فقررتِ أن تحوليها إلى "فراغ" (NaN) حتى تعالجيها لاحقاً بطريقة صحيحة
import numpy as np
df.loc[filter_typo_garage_year,'Garage Yr Blt'] = np.nan
df['Garage Yr Blt'].describe()
# Out:
# count    2770.000000
# mean     1978.049819
# std        25.159722
# min      1895.000000
# 25%      1960.000000
# 50%      1979.000000
# 75%      2002.000000
# max      2010.000000
# Name: Garage Yr Blt, dtype: float64

# %%
# لأن عمود Garage Yr Blt هو عمود أرقام (Numeric). بايثون ما بيسمح لك تحطي كلمات (Strings)
# وسط أرقام (Floats) في نفس العمود لأنه رح يعطيكي خطأ في الحسابات. لهيك استخدمنا رقم مستحيل (-1) ليعبر عن "عدم الوجود"
# Filling null values with -1
df['Garage Yr Blt']  = df['Garage Yr Blt'].fillna(-1)
df['Garage Yr Blt'].isna().sum()
# Out:
# np.int64(0)

# %%
# إنتِ عملتِ تغييرات كبيرة (حذفتِ سنة 2207، وعبيتِ الفراغات برقم -1)، وهلقيت لازم تشوفي كيف هاي التغييرات أثرت على "شكل" البيانات
# Checking the describe after filling nulls
df['Garage Yr Blt'].describe()
# Out:
# count    2930.000000
# mean     1869.978840
# std       450.406464
# min        -1.000000
# 25%      1957.000000
# 50%      1977.000000
# 75%      2001.000000
# max      2010.000000
# Name: Garage Yr Blt, dtype: float64

# %%
# بايثون بيمسك كل الأعمدة الرقمية (Numeric) في الجدول وبيحسب لها 8 إحصائيات أساسية:
# count: كم خلية مليانة (عشان تعرفي لو في نقص بيانات).
# mean: المتوسط الحسابي.
# std: الانحراف المعياري (يعني هل الأرقام قريبة من بعض ولا مشتتة؟).
# min / max: أصغر وأكبر قيمة.
# 25%, 50%, 75%: (الوسيط وتوزيع البيانات)
# Check the summary stats for the df

df.describe().round()
# Out:
#        Unnamed: 0  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# count      2930.0        2930.0    2930.0        2930.0        2930.0
# mean       1480.0          57.0   10148.0           6.0           6.0
# std         854.0          34.0    7880.0           1.0           1.0
# min           0.0          -1.0    1300.0           1.0           1.0
# 25%         741.0          43.0    7440.0           5.0           5.0
# 50%        1480.0          63.0    9436.0           6.0           5.0
# 75%        2219.0          78.0   11555.0           7.0           6.0
# max        2958.0         313.0  215245.0          10.0           9.0
#
#        Year Built  Year Remod/Add  Bsmt Unf SF  Total Bsmt SF  Bsmt Full Bath  \
# count      2930.0          2930.0       2929.0         2929.0          2928.0
# mean       1971.0          1984.0        559.0         1052.0             0.0
# std          30.0            21.0        439.0          441.0             1.0
# ...

# %%
# Check for remaining missing values
df.isna().sum()
# Out:
# Unnamed: 0        0
# MS Zoning         0
# Lot Frontage      0
# Lot Area          0
# Street            0
# Alley             0
# Utilities         0
# Neighborhood      0
# Bldg Type         0
# House Style       0
# Overall Qual      0
# Overall Cond      0
# Year Built        0
# Year Remod/Add    0
# Exter Qual        0
# Exter Cond        0
# Bsmt Unf SF       1
# Total Bsmt SF     1
# Central Air       0
# Gr Liv Area       0
# Bsmt Full Bath    2
# Bsmt Half Bath    2
# Full Bath         0
# Half Bath         0
# Bedroom           0
# Kitchen           0
# TotRms AbvGrd     0
# Garage Type       0
# Garage Yr Blt     0
# Garage Cars       1
# Garage Area       1
# Garage Qual       0
# Garage Cond       0
# Paved Drive       0
# Fence             0
# Date Sold         0
# SalePrice         0
# dtype: int64

# %%
# وهيك بايثون رح يعرض لك فقط البيوت اللي لسه "مغلبانا" وفيها فراغات، عشان تشوفيها بعينك وتعرفي شو المشكلة (هل هي فراغات بسيطة ممكن نحذفها؟ ولا لازم نعبيها؟)
# Create a filter for only rows with missing values
filter_remaining_nulls = df.isna().any(axis=1)
filter_remaining_nulls
# Out:
# PID
# 907227090    False
# 527108010    False
# 534275170    False
# 528104050    False
# 533206070    False
#              ...
# 903400030    False
# 533234020    False
# 908188140    False
# 909254050    False
# 902201120    False
# Length: 2930, dtype: bool

# %%
# Apply the filter to view only rows with missing values
df[filter_remaining_nulls]
# Out:
#            Unnamed: 0 MS Zoning  Lot Frontage  Lot Area Street    Alley  \
# PID
# 910201180         896        RM            50      9060   Pave  MISSING
# 903230120        1102        RM            99      5940   Pave  MISSING
# 908154080        2827        RL           123     47007   Pave  MISSING
#
#           Utilities Neighborhood Bldg Type House Style  ...  Garage Type  \
# PID                                                     ...
# 910201180    AllPub       IDOTRR      1Fam      2Story  ...       Detchd
# 903230120    AllPub      BrkSide      1Fam      1Story  ...       Detchd
# 908154080    AllPub      Edwards      1Fam      1Story  ...       Attchd
#
#            Garage Yr Blt  Garage Cars  Garage Area Garage Qual Garage Cond  \
# PID
# 910201180           -1.0          NaN          NaN     MISSING     MISSING
# 903230120         1946.0          1.0        280.0          TA          TA
# 908154080         1959.0          2.0        624.0          TA          TA
#
# ...

# %%
# Calculate the mean for all columns
col_means = df[num_cols].mean()
col_means
# Out:
# Unnamed: 0          1479.964505
# Lot Frontage          57.480546
# Lot Area           10147.921843
# Overall Qual           6.094881
# Overall Cond           5.563140
# Year Built          1971.356314
# Year Remod/Add      1984.266553
# Bsmt Unf SF          559.262547
# Total Bsmt SF       1051.614544
# Bsmt Full Bath         0.431352
# Bsmt Half Bath         0.061134
# Full Bath              1.566553
# Bedroom                2.854266
# Kitchen                1.044369
# TotRms AbvGrd          6.443003
# Garage Yr Blt       1869.978840
# Garage Cars            1.766815
# Garage Area          472.819734
# SalePrice         181439.404778
# dtype: float64

# %%
# Fill in remaining null values for numeric columns with the column mean
df[num_cols] = df[num_cols].fillna(col_means)
df[num_cols].isna().sum()
# Out:
# Unnamed: 0        0
# Lot Frontage      0
# Lot Area          0
# Overall Qual      0
# Overall Cond      0
# Year Built        0
# Year Remod/Add    0
# Bsmt Unf SF       0
# Total Bsmt SF     0
# Bsmt Full Bath    0
# Bsmt Half Bath    0
# Full Bath         0
# Bedroom           0
# Kitchen           0
# TotRms AbvGrd     0
# Garage Yr Blt     0
# Garage Cars       0
# Garage Area       0
# SalePrice         0
# dtype: int64

# %%
# Identify string columns
string_cols = df.select_dtypes("object").columns
string_cols
# Out:
# Index(['MS Zoning', 'Street', 'Alley', 'Utilities', 'Neighborhood',
#        'Bldg Type', 'House Style', 'Exter Qual', 'Exter Cond', 'Central Air',
#        'Gr Liv Area', 'Half Bath', 'Garage Type', 'Garage Qual', 'Garage Cond',
#        'Paved Drive', 'Fence', 'Date Sold'],
#       dtype='object')

# %%
# Explore the value counts of one feature
df['MS Zoning'].value_counts()
# Out:
# MS Zoning
# RL         2294
# RM          467
# FV          142
# RH           27
# C (all)      25
# I (all)       2
# A (agr)       2
# Name: count, dtype: int64

# %%
# Obtain the value counts for all string columns
for col in string_cols:
  print(f"Value Counts for {col}")
  print(df[col].value_counts())
  # Increasing readability by adding an empty line
  print('\n')
# Out:
# Value Counts for MS Zoning
# MS Zoning
# RL         2294
# RM          467
# FV          142
# RH           27
# C (all)      25
# I (all)       2
# A (agr)       2
# Name: count, dtype: int64
#
#
# Value Counts for Street
# Street
# Pave    2947
# Grvl      12
# Name: count, dtype: int64
#
#
# Value Counts for Alley
# Alley
# Grvl    121
# Pave     80
# Name: count, dtype: int64
#
#
# Value Counts for Utilities
# Utilities
# AllPub    2956
# NoSewr       2
# NoSeWa       1
# Name: count, dtype: int64
#
#
# Value Counts for Neighborhood
# Neighborhood
# NAmes      448
# CollgCr    271
# OldTown    242
# Edwards    196
# Somerst    186
# NridgHt    168
# Gilbert    166
# Sawyer     151
# NWAmes     132
# SawyerW    126
# Mitchel    115
# BrkSide    109
# Crawfor    104
# IDOTRR      93
# Timber      73
# NoRidge     71
# StoneBr     51
# SWISU       49
# ClearCr     44
# MeadowV     38
# BrDale      30
# Blmngtn     28
# Veenker     24
# NPkVill     23
# Blueste     10
# ...

# %%
# Check the unique values and counts of the 'Central Air' column
df['Central Air'].value_counts()
# Out:
# Central Air
# Y      2724
# N       192
# yes      38
# no        5
# Name: count, dtype: int64

# %%
# Standardize the values in the Central column
df['Central Air'] = df['Central Air'].replace({'yes':"Y",'no':'N'})
df['Central Air'].value_counts()
# Out:
# Central Air
# Y    2762
# N     197
# Name: count, dtype: int64

# %%
# Inspect the first five values for Date Sold
df['Date Sold'].head()
# Out:
# 0    03-2006
# 1    03-2006
# 2    04-2007
# 3    06-2008
# 4    02-2007
# Name: Date Sold, dtype: object

# %%
# Split the column
df['Date Sold'].str.split('-')
# Out:
# 0       [03, 2006]
# 1       [03, 2006]
# 2       [04, 2007]
# 3       [06, 2008]
# 4       [02, 2007]
#            ...
# 2954    [07, 2006]
# 2955    [06, 2008]
# 2956    [04, 2006]
# 2957    [06, 2008]
# 2958    [04, 2008]
# Name: Date Sold, Length: 2959, dtype: object

# %%
# Create two new columns based on the split by using expand = True
df['Date Sold'].str.split('-', expand=True)
# Out:
#        0     1
# 0     03  2006
# 1     03  2006
# 2     04  2007
# 3     06  2008
# 4     02  2007
# ...   ..   ...
# 2954  07  2006
# 2955  06  2008
# 2956  04  2006
# 2957  06  2008
# 2958  04  2008
#
# [2959 rows x 2 columns]

# %%
# Include column names for new columns based on split
df[['Month','Year']] = df['Date Sold'].str.split('-', expand=True)
df.head()
# Out:
#    Unnamed: 0        PID MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0           0  907227090        RL            60      7200   Pave   NaN
# 1           1  527108010        RL           134     19378   Pave   NaN
# 2           2  534275170        RL            -1     12772   Pave   NaN
# 3           3  528104050        RL           114     14803   Pave   NaN
# 4           4  533206070        FV            32      3784   Pave  Pave
#
#   Utilities Neighborhood Bldg Type  ... Garage Cars  Garage Area  Garage Qual  \
# 0    AllPub      CollgCr      1Fam  ...         1.0        297.0           TA
# 1    AllPub      Gilbert      1Fam  ...         2.0        576.0           TA
# 2    AllPub        NAmes      1Fam  ...         1.0        301.0           TA
# 3    AllPub      NridgHt      1Fam  ...         3.0       1220.0           TA
# 4    AllPub      Somerst    TwnhsE  ...         2.0        476.0           TA
#
# ...

# %%
# Drop the original column
df = df.drop(columns=['Date Sold'])
df.head()
# Out:
#    Unnamed: 0        PID MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0           0  907227090        RL            60      7200   Pave   NaN
# 1           1  527108010        RL           134     19378   Pave   NaN
# 2           2  534275170        RL            -1     12772   Pave   NaN
# 3           3  528104050        RL           114     14803   Pave   NaN
# 4           4  533206070        FV            32      3784   Pave  Pave
#
#   Utilities Neighborhood Bldg Type  ... Garage Yr Blt  Garage Cars  \
# 0    AllPub      CollgCr      1Fam  ...        1977.0          1.0
# 1    AllPub      Gilbert      1Fam  ...        2006.0          2.0
# 2    AllPub        NAmes      1Fam  ...        1960.0          1.0
# 3    AllPub      NridgHt      1Fam  ...        2007.0          3.0
# 4    AllPub      Somerst    TwnhsE  ...        2006.0          2.0
#
#    Garage Area  Garage Qual  Garage Cond Paved Drive  Fence  SalePrice  Month  \
# ...

# %%
df = df.set_index('PID')
df.head()
# Out:
#            Unnamed: 0 MS Zoning  Lot Frontage  Lot Area Street Alley  \
# PID
# 907227090           0        RL            60      7200   Pave   NaN
# 527108010           1        RL           134     19378   Pave   NaN
# 534275170           2        RL            -1     12772   Pave   NaN
# 528104050           3        RL           114     14803   Pave   NaN
# 533206070           4        FV            32      3784   Pave  Pave
#
#           Utilities Neighborhood Bldg Type House Style  ...  Garage Yr Blt  \
# PID                                                     ...
# 907227090    AllPub      CollgCr      1Fam      1Story  ...         1977.0
# 527108010    AllPub      Gilbert      1Fam      2Story  ...         2006.0
# 534275170    AllPub        NAmes      1Fam      1Story  ...         1960.0
# 528104050    AllPub      NridgHt      1Fam      1Story  ...         2007.0
# 533206070    AllPub      Somerst    TwnhsE      1Story  ...         2006.0
#
# ...

# %%
df['Full Bath'].head()
# Out:
# PID
# 907227090    1
# 527108010    2
# 534275170    1
# 528104050    2
# 533206070    2
# Name: Full Bath, dtype: int64

# %%
# Preview first 5 values
df['Bsmt Full Bath'].head()
# Out:
# PID
# 907227090    0.0
# 527108010    1.0
# 534275170    0.0
# 528104050    1.0
# 533206070    1.0
# Name: Bsmt Full Bath, dtype: float64

# %%
# Add values from two columns to create a new column
df['Total Full Baths'] = df['Full Bath'] + df['Bsmt Full Bath']
df['Total Full Baths'].head()
# Out:
# PID
# 907227090    1.0
# 527108010    3.0
# 534275170    1.0
# 528104050    3.0
# 533206070    3.0
# Name: Total Full Baths, dtype: float64

# %%
# Check value counts
df['Half Bath'].value_counts()
# Out:
# Half Bath
# 0    1855
# 1    1076
# 2      25
# ?       3
# Name: count, dtype: int64

# %%
# Replace ? with null placeholder 999
df['Half Bath'] = df['Half Bath'].replace('?', 999)
df['Half Bath'].value_counts()
# Out:
# Half Bath
# 0      1855
# 1      1076
# 2        25
# 999       3
# Name: count, dtype: int64

# %%
# Convert the column to a float
df['Half Bath'] = df['Half Bath'].astype(float)
df['Half Bath'].dtype
# Out:
# dtype('float64')

# %%
# Add values from two columns to create a new column
df['Total Half Baths'] = df['Half Bath'] + df['Bsmt Half Bath']
df['Total Half Baths'].head()
# Out:
# PID
# 907227090    0.0
# 527108010    1.0
# 534275170    0.0
# 528104050    0.0
# 533206070    0.0
# Name: Total Half Baths, dtype: float64

# %%
# Drop the original columns
df = df.drop(columns=['Half Bath', 'Bsmt Half Bath'])
df.head()
# Out:
#            Unnamed: 0 MS Zoning  Lot Frontage  Lot Area Street Alley  \
# PID
# 907227090           0        RL            60      7200   Pave   NaN
# 527108010           1        RL           134     19378   Pave   NaN
# 534275170           2        RL            -1     12772   Pave   NaN
# 528104050           3        RL           114     14803   Pave   NaN
# 533206070           4        FV            32      3784   Pave  Pave
#
#           Utilities Neighborhood Bldg Type House Style  Overall Qual  \
# PID
# 907227090    AllPub      CollgCr      1Fam      1Story             5
# 527108010    AllPub      Gilbert      1Fam      2Story             7
# 534275170    AllPub        NAmes      1Fam      1Story             6
# 528104050    AllPub      NridgHt      1Fam      1Story            10
# 533206070    AllPub      Somerst    TwnhsE      1Story             8
#
#            Overall Cond  Year Built  Year Remod/Add Exter Qual Exter Cond  \
# PID
# ...

# %%
# Saving the cleaned data to Google Drive
fpath_out = "/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/ames-housing-cleaned-eda.csv"
df.to_csv(fpath_out, index=True)

# %%
# Loading and inspecting saved file
loaded = pd.read_csv(fpath_out)
loaded.head()
# Out:
#          PID MS Zoning  Lot Frontage  Lot Area Street Alley Utilities  \
# 0  907227090        RL            60      7200   Pave   NaN    AllPub
# 1  527108010        RL           134     19378   Pave   NaN    AllPub
# 2  534275170        RL            -1     12772   Pave   NaN    AllPub
# 3  528104050        RL           114     14803   Pave   NaN    AllPub
# 4  533206070        FV            32      3784   Pave  Pave    AllPub
#
#   Neighborhood Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0      CollgCr      1Fam      1Story             5             8        1972
# 1      Gilbert      1Fam      2Story             7             5        2005
# 2        NAmes      1Fam      1Story             6             8        1960
# 3      NridgHt      1Fam      1Story            10             5        2007
# 4      Somerst    TwnhsE      1Story             8             5        2006
#
#    Year Remod/Add Exter Qual Exter Cond  Bsmt Unf SF  Total Bsmt SF  \
# ...
