# %% [markdown]
# <a href="https://colab.research.google.com/github/dohaalnabahin/Data_science_and_machine_learning_Journey/blob/main/Combining_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',100)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# This filepath will work if you are using the recommended file structure
fname = "/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week03/Data/ames-housing-cleaned-eda.csv"
df = pd.read_csv(fname)
df.head()
# Out:
#          PID MS Zoning  Lot Frontage  Lot Area Street    Alley Utilities  \
# 0  907227090        RL            60      7200   Pave  MISSING    AllPub
# 1  527108010        RL           134     19378   Pave  MISSING    AllPub
# 2  534275170        RL            -1     12772   Pave  MISSING    AllPub
# 3  528104050        RL           114     14803   Pave  MISSING    AllPub
# 4  533206070        FV            32      3784   Pave     Pave    AllPub
#
#   Neighborhood Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0      CollgCr      1Fam      1Story             5             8        1972
# 1      Gilbert      1Fam      2Story             7             5        2005
# 2        NAmes      1Fam      1Story             6             8        1960
# 3      NridgHt      1Fam      1Story            10             5        2007
# 4      Somerst    TwnhsE      1Story             8             5        2006
#
# ...

# %%
# Create 2 side by side axes with a shared y axis
fig, axes = plt.subplots(ncols=2, sharey=True, figsize=(12,5))
# Plot the barplot on the left
sns.barplot(data=df, x='Bldg Type', y='Living Area Sqft',ax=axes[0]);
# Plot the stripplot on the right
sns.stripplot(data=df, x='Bldg Type', y='Living Area Sqft',ax=axes[1],
                   hue='Bldg Type', edgecolor='white', linewidth=1);

# %%
# Combine a barplot and a stripplot
ax = sns.barplot(data=df, x='Bldg Type', y='Living Area Sqft')
sns.stripplot(data=df, x='Bldg Type', y='Living Area Sqft',ax=ax,
                   hue='Bldg Type', edgecolor='white', linewidth=1);

# %%
# Futher adjustments to improve visibility.
ax = sns.barplot(data=df, x='Bldg Type', y='Living Area Sqft', edgecolor='black')
sns.stripplot(data=df, x='Bldg Type', y='Living Area Sqft',ax=ax,
              hue='Bldg Type', edgecolor='white',
              linewidth=.5, s=2,alpha=0.5) ;

# %%
# Define the custom line properties
line_kws = dict(color='black')
# Define the custom marker properties
scatter_kws = dict(edgecolor='white')
# The plot including a title
g = sns.lmplot(data=df, x="Living Area Sqft", y="SalePrice",
               scatter_kws=scatter_kws,
                hue="Central Air");
g.ax.set_title("LM Plot");

# %%
# Create an lmplot that is 50% wider than the default
g = sns.lmplot(data=df, x="Living Area Sqft", y="SalePrice",
               scatter_kws=scatter_kws,
                hue="Central Air", aspect=1.5);

# %%
# Create an lmplot with a separate subplot for each value in the "col" column
g = sns.lmplot(data=df, x="Living Area Sqft", y="SalePrice",
               scatter_kws=scatter_kws,
                col='Central Air', aspect=1.2,);

# %%
# Combine hue and col for the same column
g = sns.lmplot(data=df, x="Living Area Sqft", y="SalePrice",
               scatter_kws=scatter_kws,
                col='Central Air', aspect=1.2,
               hue='Central Air',
               );

# %%
# Demonstrating using col_wrap when the col column has many categories
g = sns.lmplot(data=df, x="Living Area Sqft", y="SalePrice",
               scatter_kws=scatter_kws,
               hue='Bldg Type', aspect=1,
               col='Bldg Type', col_wrap =2)
