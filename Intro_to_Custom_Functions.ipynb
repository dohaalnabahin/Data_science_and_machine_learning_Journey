# %% [markdown]
# <a href="https://colab.research.google.com/github/dohaalnabahin/Python-Learning-Journey/blob/main/Intro_to_Custom_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# define a custom function to subtract one value from another
def return_difference(a, b):
  return a - b
  # call our custom function
return_difference(8, 3)
# Out:
# 5

# %%
# Define variables
cars = 30
trucks = 10
return_difference(cars, trucks)
# Out:
# 20

# %%
# Switch the order of arguments when calling the function
return_difference(trucks, cars)
# Out:
# -20

# %%
# define a variable based on the return of our custom function
c = return_difference(cars, trucks)
c
# Out:
# 20

# %%
# Custom function to calculate celsius from fahrenheit with return statement
def convert_f_to_c(f_temp):
  # Convert Farhenheit to Celsius
  c_temp = (f_temp - 32) * (5/9)
  # Round Celsius to 2 decimal places
  c_temp = round(c_temp, 2)
  return c_temp

  # Test the function with the return statement
convert_f_to_c(32)
# Out:
# 0.0

# %%
# Store results of a function in a variable
function_output = convert_f_to_c(66)
print(function_output)
# Out:
# 18.89

# %%
# define a list of temperatures
week_1 = [45, 55, 49, 60, 52, 55, 58]
# Define a function to print the minimum temperature
def extremes(temps):
  min_temp = min(temps)
  print(f'The minimum temperature was {min_temp}.')
  max_temp = max(temps)
  print(f'The maximum temperature was {max_temp}.')
    # Test our function
extremes(week_1)
# Out:
# The minimum temperature was 45.
# The maximum temperature was 60.

# %%
# Add an rgument to the function to choose the minimum or the maximum
def extremes(temps, direction = "minimum"):
  if direction == "minimum":
    min_temp = min(temps)
    print(f"The minimum temperature was {min_temp}.")
  elif direction == "maximum":
    max_temp = max(temps)
    print(f"The maximum temperature was {max_temp}.")
  else:
    print("The second argument must be 'maximum' or 'minimum'.")

# Call the function using the 'maximum' argument
extremes(week_1,'maximum')

# Call the function using the 'minimum' argument argument
extremes(week_1, direction = 'minimum')

# Call the function with a different argument
extremes(week_1, 'min')

# Call the function with only the first argument
extremes(week_1)
# Out:
# The maximum temperature was 60.
# The minimum temperature was 45.
# The second argument must be 'maximum' or 'minimum'.
# The minimum temperature was 45.
